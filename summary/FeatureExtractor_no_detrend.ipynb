# %% [markdown]
# # Feature Extraction for VSX → TESS Variable-Star Classification
#
# This notebook extracts interpretable machine-learning features from standardized TESS light-curve FITS files.
#
# It is designed for the current research pipeline:
#
# - **Input**: metadata parquet containing `lightCurvePath`
# - **Light curve source**: standardized FITS files already saved by `TessDataDownloader.py`
# - **Output**: feature parquet, one row per star
# - **Parallel processing**: configurable thread pool, default `WorkerCount = 16`
#
# Important leakage rule:
#
# > Feature extraction here is safe before train/validation/test split because every feature is computed independently per star.
# > Dataset-level scaling, PCA, feature selection, and model fitting must happen only after train/validation/test split.

# %% [markdown]
# # Complete Feature List
#
# The actual output parquet contains **59 columns**. The list below matches the schema of:
#
# ```text
# TESS_features_2026_07_29_v1_input.parquet
# ```
#
# ## 1. Identification and Metadata Columns
#
# | Column | Meaning | Method / Source |
# |---|---|---|
# | `family` | VSX family used as the classification target | copied from input metadata |
# | `VSXType` | original or mapped VSX variability type | copied from input metadata |
# | `VSXId` | VSX identifier | copied from input metadata |
# | `lightCurvePath` | standardized or conditionally detrended FITS path used by feature extraction | copied from input metadata |
# | `rawLightCurvePath` | original raw FITS path | copied from input metadata |
# | `QualityLabel` | resolved light-curve quality label | QualityLabel summarizes the fraction of cadences rejected by the TESS quality mask: clean (<10%), acceptable (10–<25%), caution (25–<40%), poor (≥40%), or missing when no usable light curve was acquired. QualityScore is the numeric encoding of those labels: 0, 1, 2, 3, and 4 respectively. A higher score therefore indicates worse or unavailable data quality. It is an ordinal pipeline-quality indicator, not a physical measurement of the star. TESS quality mask is a set of quality flags assigned by the TESS mission to identify observations that may be unreliable because of spacecraft or instrument effects, such as momentum dumps, scattered light, cosmic rays, or other anomalies. These flagged cadences are typically excluded from scientific analysis. QualityLabel summarizes the fraction of cadences removed by this mask, providing an overall indicator of the reliability of the light curve. |
# | `QualityScore` | numeric encoding of `QualityLabel` | `clean=0`, `acceptable=1`, `caution=2`, `poor=3`, `missing=4` |
# | `Provenance` | source of the light curve | obtained from `provenance`, then `author`; otherwise `missing` |
# | `ProvenanceScore` | numeric encoding of provenance | `SPOC=0`, `QLP=1`, `TESSCut=2`; unrecognized values become `NaN` |
# | `OriginalFluxMedian` | median flux before standardization or detrending | Median flux of the original downloaded light curve before standardization or detrending. |
# | `OriginalFluxStd` | flux standard deviation before standardization or detrending | Flux standard deviation of the original downloaded light curve before standardization or detrending. |
# | `OriginalFluxSnr` | original signal-to-noise estimate |  * See note below |
# | `LowSnr` | low-SNR indicator | boolean conversion of input metadata field `lowSNR` |
# | `LowQualityLightCurve` | low-quality-light-curve indicator |
#
# Note:
# * Boolean quality-control flag indicating whether the original downloaded light curve exhibits significant quality issues, such as low signal-to-noise ratio or an excessive fraction of cadences rejected by the TESS quality mask. Light curves flagged as `True` should be interpreted with additional caution during subsequent analysis.
#
# **OriginalFluxSnr** — Estimated signal-to-noise ratio (SNR) of the original downloaded light curve before standardization or detrending, calculated as:
#
# $$
# \text{FluxSnr} = \frac{|\mathrm{median}(\mathrm{Flux})|}{\mathrm{std}(\mathrm{Flux})}
# $$
#
# A larger value indicates that the signal is stronger relative to the background scatter. This metric is used during data-quality control to identify low-SNR light curves (`LowSnr` is set when `FluxSnr < 3.0`).
#
# ## 2. Data Coverage and Cadence Features
#
# | Column | Meaning | Method |
# |---|---|---|
# | `CadenceCount` | number of retained finite time-and-flux observations | `len(Flux)` after loading and finite-value filtering |
# | `TimeSpanDays` | total retained observing baseline in days | `max(Time) - min(Time)` |
# | `MedianCadenceDays` | median spacing between adjacent retained observations | `median(diff(Time))` |
#
# ## 3. Flux Distribution Features
#
# | Column | Meaning | Method |
# |---|---|---|
# | `FluxStd` | population standard deviation of retained flux | `std(Flux)` |
# | `FluxMedian` | median retained flux | 50th percentile |
# | `FluxMad` | median absolute deviation from the median | `median(abs(Flux - FluxMedian))` |
# | `FluxP05` | 5th percentile | `percentile(Flux, 5)` |
# | `FluxP10` | 10th percentile | `percentile(Flux, 10)` |
# | `FluxP90` | 90th percentile | `percentile(Flux, 90)` |
# | `FluxP95` | 95th percentile | `percentile(Flux, 95)` |
# | `FluxIqr` | interquartile range | `FluxP75 - FluxP25` |
# | `FluxAmplitude` | full observed flux range | `FluxMax - FluxMin` |
# | `FluxPercentAmplitude95To5` | robust 5th-to-95th percentile amplitude | `FluxP95 - FluxP05` |
# | `FluxPercentAmplitude90To10` | robust 10th-to-90th percentile amplitude | `FluxP90 - FluxP10` |
# | `FluxSkewness` | bias-corrected asymmetry of the flux distribution | `scipy.stats.skew(Flux, bias=False)` |
# | `FluxKurtosis` | bias-corrected excess kurtosis of the flux distribution | `scipy.stats.kurtosis(Flux, bias=False)` |
#
# `FluxSkewness` becomes `NaN` when there are fewer than three retained observations or the flux scatter is effectively zero. `FluxKurtosis` becomes `NaN` when there are fewer than four retained observations or the flux scatter is effectively zero.
#
# ## 4. Tail-Asymmetry Features
#
# | Column | Meaning | Method |
# |---|---|---|
# | `TailUpper` | distance from the median to the 95th percentile | `FluxP95 - FluxMedian` |
# | `TailLower` | distance from the 5th percentile to the median | `FluxMedian - FluxP05` |
# | `TailAsymmetry` | difference between upper- and lower-tail strengths | `TailUpper - TailLower` |
# | `TailRatio` | upper-tail strength relative to lower-tail strength | `TailUpper / (TailLower + Eps)` through safe division |
#
# A positive `TailAsymmetry` indicates a stronger upper flux tail. A negative value indicates a stronger lower flux tail.
#
# ## 5. Time-Domain Variability Features
#
# | Column | Meaning | Method |
# |---|---|---|
# | `EtaVonNeumann` | point-to-point variation relative to total variance | `sum(diff(Flux)^2) / ((N - 1) * var(Flux))` |
# | `MaxAbsSlope` | largest absolute finite rate of flux change | `max(abs(diff(Flux) / diff(Time)))`, excluding invalid or zero time differences |
# | `MedianAbsSuccessiveDiff` | typical absolute point-to-point flux change | `median(abs(diff(Flux)))` |
# | `FractionBeyond1Std` | fraction of observations more than one standard deviation from the mean | `mean(abs(Flux - FluxMean) > FluxStd)` |
# | `FractionBeyond2Std` | fraction of observations more than two standard deviations from the mean | `mean(abs(Flux - FluxMean) > 2 * FluxStd)` |
#
# ## 6. Lomb-Scargle Period Features
#
# The period search is constrained by:
#
# - minimum period: `MinPeriodDays`
# - effective maximum period: `min(MaxPeriodDays, 0.9 * TimeSpanDays)`
# - grid density: `SamplesPerPeak`
#
# Lomb-Scargle uses flux uncertainty weights only when a valid, positive `FluxErr` array is available. Otherwise, it runs unweighted.
#
# | Column | Meaning | Method |
# |---|---|---|
# | `LsBestPeriod` | period corresponding to the largest periodogram power | `1 / LsBestFrequency` |
# | `LsBestFrequency` | frequency corresponding to the largest periodogram power | `Frequency[argmax(Power)]` |
# | `LsMaxPower` | highest Lomb-Scargle power | `max(Power)` |
# | `LsFalseAlarmProbability` | false-alarm probability of the highest sampled power | `LombScargle.false_alarm_probability(LsMaxPower)` |
# | `LsPeriod2` | period corresponding to the second-highest sampled power | inverse of the second-ranked frequency |
# | `LsPeriod3` | period corresponding to the third-highest sampled power | inverse of the third-ranked frequency |
# | `LsPower2` | second-highest sampled periodogram power | second-ranked value of `Power` |
# | `LsPower3` | third-highest sampled periodogram power | third-ranked value of `Power` |
# | `LsPowerRatio21` | second-highest power relative to the highest power | `LsPower2 / LsMaxPower` |
# | `LsPowerRatio31` | third-highest power relative to the highest power | `LsPower3 / LsMaxPower` |
# | `LsPeriodRatio21` | second-ranked period relative to the best period | `LsPeriod2 / LsBestPeriod` |
# | `LsPeriodRatio31` | third-ranked period relative to the best period | `LsPeriod3 / LsBestPeriod` |
#
# `LsPeriod2` and `LsPeriod3` currently represent the second- and third-highest sampled frequency-grid powers. The implementation does not require them to be separate independent local peaks.
#
# ## 7. Phase-Folded Morphology Features
#
# The light curve is folded using `LsBestPeriod`, divided into `PhaseBinCount` bins, and summarized using the median flux in each nonempty bin. At least five nonempty bins are required.
#
# | Column | Meaning | Method |
# |---|---|---|
# | `PhaseCurveStd` | standard deviation of the median-binned phase curve | `std(BinnedFlux)` |
# | `PhaseCurveRange` | full range of the median-binned phase curve | `max(BinnedFlux) - min(BinnedFlux)` |
# | `PhaseCurveSmoothness` | scatter of cyclic differences between adjacent phase bins | standard deviation of cyclic first differences |
# | `PhasePeakPhase` | median phase coordinate of the maximum-flux bin | `BinnedPhase[argmax(BinnedFlux)]` |
# | `PhaseTroughPhase` | median phase coordinate of the minimum-flux bin | `BinnedPhase[argmin(BinnedFlux)]` |
# | `PhasePeakToTroughPhaseDelta` | shortest cyclic phase separation between peak and trough | `min(abs(PeakPhase - TroughPhase), 1 - abs(PeakPhase - TroughPhase))` |
#
# ## 8. Extraction Status Columns
#
# | Column | Meaning | Method / Source |
# |---|---|---|
# | `FeatureStatus` | final outcome of feature extraction for the row | possible values include `ok`, `missing_lightcurve_path`, `missing_lightcurve_file`, `too_few_cadences`, and `failed` |
# | `FeatureError` | diagnostic explanation when extraction is not successful | missing path, missing file, retained-cadence count, or exception text |
#
# ## Verified Column Count
#
# | Category | Columns |
# |---|---:|
# | Identification and metadata | 14 |
# | Coverage and cadence | 3 |
# | Flux distribution | 13 |
# | Tail asymmetry | 4 |
# | Time-domain variability | 5 |
# | Lomb-Scargle | 12 |
# | Phase-folded morphology | 6 |
# | Extraction status | 2 |
# | **Actual total** | **59** |
#
# The following fields from the earlier documentation are **not present** in the actual parquet schema and have therefore been removed:
#
# ```text
# Name
# ticId
# bestTicId
# ticDistanceArcmin
# trendFlag
# trendScore
# adfPValue
# ```
#
# ## Feature Redundancy Reduction
#
# To improve the stability and interpretability of feature-importance analysis, the extractor no longer outputs:
#
# ```text
# FluxVariance
# FluxMean
# FluxP25
# FluxP75
# FluxMin
# FluxMax
# FluxP01
# FluxP99
# ```
#
# The retained features preserve the main scientific information: `FluxStd` for standard dispersion, `FluxMedian` for central location, `FluxIqr` for robust spread, `FluxAmplitude` for the full range, and `FluxP05`/`FluxP95` plus the tail features for robust amplitude and asymmetry. The expected output schema is reduced from 67 to **59 columns**.

# %% [markdown]
# # Imports and Configuration

# %%
from __future__ import annotations

import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path
from typing import Any, Dict, Optional, Tuple

import numpy as np
import pandas as pd

import lightkurve as lk
from astropy.io import fits
from astropy.timeseries import LombScargle
from scipy.stats import skew, kurtosis

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s:%(name)s:%(message)s",
)

Logger = logging.getLogger("FeatureExtractorNotebook")

# Update these paths for your local repo.
# InputMetadataPath = Path("../trend_detection/TESSAugmented_QC_trend.parquet")
InputMetadataPath = Path("/data/projects/TESS-research/data_pipeline/TESSCache/TESSAugmented_QC.parquet")
OutputFeaturePath = Path("/data/projects/TESS-research/feature_extraction/TESS_features.parquet")
# InputMetadataPath = Path("/data/projects/TESS-research/detrend_tesscut/output/TESSAugmented_QC_tesscut_conditional_detrended.parquet")
# OutputFeaturePath = Path("TESS_conditional_detrended_features.parquet")

MinPeriodDays = 0.05
MaxPeriodDays = 100.0
SamplesPerPeak = 10
MinCadences = 100
PhaseBinCount = 20
WorkerCount = 16
Eps = 1e-12

QualityScoreMap = {
    "clean": 0,
    "acceptable": 1,
    "caution": 2,
    "poor": 3,
    "missing": 4,
}

ProvenanceScoreMap = {
    "SPOC": 0,
    "QLP": 1,
    "TESSCut": 2,
}

# %% [markdown]
# # Utility Functions

# %%
def SafeFloat(Value: Any) -> float:
    try:
        FloatValue = float(Value)
    except Exception:
        return np.nan
    return FloatValue if np.isfinite(FloatValue) else np.nan


def SafeBool(Value: Any) -> bool:
    if Value is None:
        return False
    if isinstance(Value, float) and pd.isna(Value):
        return False
    return bool(Value)


def SafeDivide(Numerator: float, Denominator: float, Eps: float = Eps) -> float:
    if not np.isfinite(Numerator) or not np.isfinite(Denominator) or abs(Denominator) < Eps:
        return np.nan
    return float(Numerator / Denominator)


def ResolvePath(PathValue: Any, MetadataPath: Path) -> Optional[Path]:
    if PathValue is None:
        return None
    if isinstance(PathValue, float) and pd.isna(PathValue):
        return None

    PathObj = Path(str(PathValue))
    if PathObj.is_absolute() and PathObj.exists():
        return PathObj
    if PathObj.exists():
        return PathObj

    CandidatePath = MetadataPath.parent / PathObj
    if CandidatePath.exists():
        return CandidatePath

    return PathObj

# %% [markdown]
# # Light Curve Loading

# %%
def LoadLightCurve(LightCurvePath: Path) -> Tuple[np.ndarray, np.ndarray, Optional[np.ndarray]]:
    """Load a light curve while treating flux uncertainty as optional.

    Time and flux determine whether a cadence is scientifically usable.
    FluxErr is retained only when it is aligned with the loaded arrays and all
    retained uncertainty values are finite and strictly positive. Invalid or
    missing uncertainty therefore downgrades Lomb-Scargle from weighted to
    unweighted analysis instead of removing otherwise valid QLP cadences.
    """

    def FirstAvailableColumn(ColumnNames: list[str], CandidateNames: list[str]) -> Optional[str]:
        NameMap = {Name.upper(): Name for Name in ColumnNames}
        for CandidateName in CandidateNames:
            MatchedName = NameMap.get(CandidateName.upper())
            if MatchedName is not None:
                return MatchedName
        return None

    def ReadGenericFitsTable(FitsPath: Path) -> Tuple[np.ndarray, np.ndarray, Optional[np.ndarray]]:
        with fits.open(str(FitsPath), memmap=False) as Hdul:
            TableData = None

            for Hdu in Hdul:
                Data = getattr(Hdu, "data", None)
                if Data is not None and getattr(Data, "dtype", None) is not None and Data.dtype.names:
                    TableData = Data
                    break

            if TableData is None:
                raise ValueError("No FITS binary table with named columns was found")

            ColumnNames = list(TableData.dtype.names)

            TimeColumn = FirstAvailableColumn(
                ColumnNames,
                ["TIME", "TMID", "BJD"],
            )
            FluxColumn = FirstAvailableColumn(
                ColumnNames,
                ["FLUX", "SAP_FLUX", "PDCSAP_FLUX", "KSPSAP_FLUX", "DET_FLUX", "NORM_FLUX"],
            )
            FluxErrColumn = FirstAvailableColumn(
                ColumnNames,
                ["FLUX_ERR", "SAP_FLUX_ERR", "PDCSAP_FLUX_ERR", "KSPSAP_FLUX_ERR", "ERR_FLUX"],
            )

            if TimeColumn is None or FluxColumn is None:
                raise ValueError(
                    f"Required time/flux columns are missing. Available columns: {ColumnNames}"
                )

            Time = np.asarray(TableData[TimeColumn], dtype=float).reshape(-1)
            Flux = np.asarray(TableData[FluxColumn], dtype=float).reshape(-1)
            FluxErr = None

            if FluxErrColumn is not None:
                FluxErr = np.asarray(TableData[FluxErrColumn], dtype=float).reshape(-1)

            return Time, Flux, FluxErr

    def ExtractFromLightkurve(LightCurve) -> Tuple[np.ndarray, np.ndarray, Optional[np.ndarray]]:
        Time = np.asarray(
            getattr(LightCurve.time, "value", LightCurve.time),
            dtype=float,
        ).reshape(-1)

        Flux = np.asarray(
            getattr(LightCurve.flux, "value", LightCurve.flux),
            dtype=float,
        ).reshape(-1)

        FluxErr = None
        if hasattr(LightCurve, "flux_err") and LightCurve.flux_err is not None:
            FluxErr = np.asarray(
                getattr(LightCurve.flux_err, "value", LightCurve.flux_err),
                dtype=float,
            ).reshape(-1)

        return Time, Flux, FluxErr

    LightCurvePath = Path(LightCurvePath)

    if not LightCurvePath.exists():
        raise FileNotFoundError(str(LightCurvePath))

    Time = None
    Flux = None
    FluxErr = None
    ReadErrors = []

    # Attempt 1: standard lightkurve reader.
    try:
        LightCurve = lk.read(str(LightCurvePath))
        Time, Flux, FluxErr = ExtractFromLightkurve(LightCurve)
    except Exception as Exc:
        ReadErrors.append(f"generic lk.read: {Exc!r}")

    # Attempt 2: QLP-specific reader.
    if Time is None or Flux is None:
        try:
            LightCurve = lk.read(
                str(LightCurvePath),
                author="QLP",
                flux_column="kspsap_flux",
            )
            Time, Flux, FluxErr = ExtractFromLightkurve(LightCurve)
        except Exception as Exc:
            ReadErrors.append(f"QLP lk.read: {Exc!r}")

    # Attempt 3: direct FITS table parsing.
    if Time is None or Flux is None:
        try:
            Time, Flux, FluxErr = ReadGenericFitsTable(LightCurvePath)
        except Exception as Exc:
            ReadErrors.append(f"generic FITS parsing: {Exc!r}")
            raise ValueError(
                "Unable to read light curve. " + " | ".join(ReadErrors)
            ) from Exc

    if Time.shape != Flux.shape:
        raise ValueError(
            f"Time/Flux shape mismatch: Time={Time.shape}, Flux={Flux.shape}"
        )

    # Only Time and Flux define a valid cadence.
    CadenceMask = np.isfinite(Time) & np.isfinite(Flux)

    FilteredTime = Time[CadenceMask]
    FilteredFlux = Flux[CadenceMask]
    FilteredFluxErr = None

    # FluxErr is optional. It must never remove otherwise valid Time/Flux rows.
    if FluxErr is not None:
        if FluxErr.shape == Time.shape:
            CandidateFluxErr = FluxErr[CadenceMask]
            ValidFluxErr = np.isfinite(CandidateFluxErr) & (CandidateFluxErr > 0)

            if len(CandidateFluxErr) > 0 and np.all(ValidFluxErr):
                FilteredFluxErr = CandidateFluxErr
            else:
                Logger.debug(
                    "Ignoring unusable flux_err for %s: %d/%d retained values are finite and positive",
                    LightCurvePath,
                    int(np.sum(ValidFluxErr)),
                    len(CandidateFluxErr),
                )
        else:
            Logger.debug(
                "Ignoring flux_err shape mismatch for %s: flux_err=%s, time=%s",
                LightCurvePath,
                FluxErr.shape,
                Time.shape,
            )

    # Keep samples in chronological order.
    Order = np.argsort(FilteredTime)
    FilteredTime = FilteredTime[Order]
    FilteredFlux = FilteredFlux[Order]

    if FilteredFluxErr is not None:
        FilteredFluxErr = FilteredFluxErr[Order]

    return FilteredTime, FilteredFlux, FilteredFluxErr

# %% [markdown]
# # Identification and Metadata Features

# %%
def ExtractIdentifierAndMetadataFeatures(Row: pd.Series) -> Dict[str, Any]:
    Result: Dict[str, Any] = {}

    ColumnsToPreserve = [
        "family", "VSXType", "VSXId", "Name", "ticId", "bestTicId",
        "ticDistanceArcmin", "lightCurvePath", "rawLightCurvePath",
        "trendFlag", "trendScore", "adfPValue",
    ]

    for ColumnName in ColumnsToPreserve:
        if ColumnName in Row.index:
            Result[ColumnName] = Row.get(ColumnName)

    QualityValue = Row.get("quality", Row.get("fitsQcStatus", Row.get("lightCurveQuality", np.nan)))
    ProvenanceValue = Row.get("provenance", Row.get("author", np.nan))

    QualityLabel = str(QualityValue) if not pd.isna(QualityValue) else "missing"
    ProvenanceLabel = str(ProvenanceValue) if not pd.isna(ProvenanceValue) else "missing"

    Result.update({
        "QualityLabel": QualityLabel,
        "QualityScore": QualityScoreMap.get(QualityLabel, np.nan),
        "Provenance": ProvenanceLabel,
        "ProvenanceScore": ProvenanceScoreMap.get(ProvenanceLabel, np.nan),
        "OriginalFluxMedian": SafeFloat(Row.get("fluxMedian", np.nan)),
        "OriginalFluxStd": SafeFloat(Row.get("fluxStd", np.nan)),
        "OriginalFluxSnr": SafeFloat(Row.get("fluxSnr", np.nan)),
        "LowSnr": SafeBool(Row.get("lowSNR", False)),
        "LowQualityLightCurve": SafeBool(Row.get("lowQualityLightCurve", False)),
    })
    return Result

# %% [markdown]
# # Data Coverage and Flux Distribution Features

# %%
def ExtractBasicStatisticalFeatures(Time: np.ndarray, Flux: np.ndarray) -> Dict[str, float]:
    CadenceCount = len(Flux)
    P01, P05, P10, P25, P50, P75, P90, P95, P99 = np.percentile(
        Flux, [1, 5, 10, 25, 50, 75, 90, 95, 99]
    )
    FluxStd = float(np.std(Flux))

    return {
        "CadenceCount": float(CadenceCount),
        "TimeSpanDays": float(np.max(Time) - np.min(Time)) if CadenceCount > 1 else np.nan,
        "MedianCadenceDays": float(np.median(np.diff(Time))) if CadenceCount > 2 else np.nan,
        "FluxStd": FluxStd,
        "FluxMedian": float(P50),
        "FluxMad": float(np.median(np.abs(Flux - P50))),
        "FluxP05": float(P05),
        "FluxP10": float(P10),
        "FluxP90": float(P90),
        "FluxP95": float(P95),
        "FluxIqr": float(P75 - P25),
        "FluxAmplitude": float(np.max(Flux) - np.min(Flux)),
        "FluxPercentAmplitude95To5": float(P95 - P05),
        "FluxPercentAmplitude90To10": float(P90 - P10),
        "FluxSkewness": float(skew(Flux, bias=False)) if CadenceCount >= 3 and FluxStd > Eps else np.nan,
        "FluxKurtosis": float(kurtosis(Flux, bias=False)) if CadenceCount >= 4 and FluxStd > Eps else np.nan,
    }

# %% [markdown]
# # Tail-Asymmetry Features

# %%
def ExtractTailAsymmetryFeatures(Flux: np.ndarray) -> Dict[str, float]:
    P05, P50, P95 = np.percentile(Flux, [5, 50, 95])

    TailUpper = float(P95 - P50)
    TailLower = float(P50 - P05)
    TailAsymmetry = float(TailUpper - TailLower)
    TailRatio = SafeDivide(TailUpper, TailLower + Eps)

    return {
        "TailUpper": TailUpper,
        "TailLower": TailLower,
        "TailAsymmetry": TailAsymmetry,
        "TailRatio": TailRatio,
    }

# %% [markdown]
# # Time-Domain Variability Features

# %%
def ExtractVariabilityFeatures(Time: np.ndarray, Flux: np.ndarray) -> Dict[str, float]:
    CadenceCount = len(Flux)
    if CadenceCount < 3:
        return {
            "EtaVonNeumann": np.nan,
            "MaxAbsSlope": np.nan,
            "MedianAbsSuccessiveDiff": np.nan,
            "FractionBeyond1Std": np.nan,
            "FractionBeyond2Std": np.nan,
        }

    FluxMean = float(np.mean(Flux))
    FluxStd = float(np.std(Flux))
    FluxVariance = float(np.var(Flux))
    FluxDiff = np.diff(Flux)
    TimeDiff = np.diff(Time)

    ValidTimeDiff = np.isfinite(TimeDiff) & (np.abs(TimeDiff) > Eps)
    Slopes = FluxDiff[ValidTimeDiff] / TimeDiff[ValidTimeDiff] if np.any(ValidTimeDiff) else np.array([])

    Eta = np.sum(FluxDiff ** 2) / ((CadenceCount - 1) * FluxVariance) if FluxVariance > Eps else np.nan

    return {
        "EtaVonNeumann": float(Eta) if np.isfinite(Eta) else np.nan,
        "MaxAbsSlope": float(np.max(np.abs(Slopes))) if Slopes.size else np.nan,
        "MedianAbsSuccessiveDiff": float(np.median(np.abs(FluxDiff))),
        "FractionBeyond1Std": float(np.mean(np.abs(Flux - FluxMean) > FluxStd)) if FluxStd > Eps else np.nan,
        "FractionBeyond2Std": float(np.mean(np.abs(Flux - FluxMean) > 2 * FluxStd)) if FluxStd > Eps else np.nan,
    }

# %% [markdown]
# # Lomb-Scargle Period Features

# %%
def ExtractLombScargleFeatures(Time: np.ndarray, Flux: np.ndarray, FluxErr: Optional[np.ndarray]) -> Dict[str, float]:
    Result = {
        "LsBestPeriod": np.nan,
        "LsBestFrequency": np.nan,
        "LsMaxPower": np.nan,
        "LsFalseAlarmProbability": np.nan,
        "LsPeriod2": np.nan,
        "LsPeriod3": np.nan,
        "LsPower2": np.nan,
        "LsPower3": np.nan,
        "LsPowerRatio21": np.nan,
        "LsPowerRatio31": np.nan,
        "LsPeriodRatio21": np.nan,
        "LsPeriodRatio31": np.nan,
    }

    if len(Flux) < MinCadences:
        return Result

    TimeSpan = float(np.max(Time) - np.min(Time))
    if not np.isfinite(TimeSpan) or TimeSpan <= 0:
        return Result

    MaxPeriod = min(MaxPeriodDays, 0.9 * TimeSpan)
    if MaxPeriod <= MinPeriodDays:
        return Result

    CenteredFlux = Flux - np.nanmedian(Flux)

    try:
        if FluxErr is not None and len(FluxErr) == len(Flux) and np.all(np.isfinite(FluxErr)):
            LombScargleModel = LombScargle(Time, CenteredFlux, dy=FluxErr)
        else:
            LombScargleModel = LombScargle(Time, CenteredFlux)

        Frequency, Power = LombScargleModel.autopower(
            minimum_frequency=1.0 / MaxPeriod,
            maximum_frequency=1.0 / MinPeriodDays,
            samples_per_peak=SamplesPerPeak,
        )

        FiniteMask = np.isfinite(Frequency) & np.isfinite(Power) & (Frequency > 0)
        Frequency = Frequency[FiniteMask]
        Power = Power[FiniteMask]
        if len(Power) == 0:
            return Result

        Order = np.argsort(Power)[::-1]
        BestFrequency = float(Frequency[Order[0]])
        BestPeriod = float(1.0 / BestFrequency)
        BestPower = float(Power[Order[0]])

        Result.update({
            "LsBestPeriod": BestPeriod,
            "LsBestFrequency": BestFrequency,
            "LsMaxPower": BestPower,
            "LsFalseAlarmProbability": float(LombScargleModel.false_alarm_probability(BestPower)),
        })

        if len(Order) > 1:
            Period2 = float(1.0 / Frequency[Order[1]])
            Power2 = float(Power[Order[1]])
            Result.update({
                "LsPeriod2": Period2,
                "LsPower2": Power2,
                "LsPowerRatio21": SafeDivide(Power2, BestPower),
                "LsPeriodRatio21": SafeDivide(Period2, BestPeriod),
            })

        if len(Order) > 2:
            Period3 = float(1.0 / Frequency[Order[2]])
            Power3 = float(Power[Order[2]])
            Result.update({
                "LsPeriod3": Period3,
                "LsPower3": Power3,
                "LsPowerRatio31": SafeDivide(Power3, BestPower),
                "LsPeriodRatio31": SafeDivide(Period3, BestPeriod),
            })

    except Exception as Exc:
        Logger.debug("Lomb-Scargle failed: %s", Exc)

    return Result

# %% [markdown]
# # Phase-Folded Morphology Features

# %%
def ExtractPhaseFeatures(Time: np.ndarray, Flux: np.ndarray, Period: float) -> Dict[str, float]:
    Result = {
        "PhaseCurveStd": np.nan,
        "PhaseCurveRange": np.nan,
        "PhaseCurveSmoothness": np.nan,
        "PhasePeakPhase": np.nan,
        "PhaseTroughPhase": np.nan,
        "PhasePeakToTroughPhaseDelta": np.nan,
    }

    if not np.isfinite(Period) or Period <= 0 or len(Flux) < MinCadences:
        return Result

    try:
        Phase = (Time % Period) / Period
        Order = np.argsort(Phase)
        Phase = Phase[Order]
        Flux = Flux[Order]

        BinEdges = np.linspace(0.0, 1.0, PhaseBinCount + 1)
        BinIndex = np.digitize(Phase, BinEdges) - 1

        BinnedPhase = []
        BinnedFlux = []

        for BinNumber in range(PhaseBinCount):
            BinMask = BinIndex == BinNumber
            if np.any(BinMask):
                BinnedPhase.append(float(np.median(Phase[BinMask])))
                BinnedFlux.append(float(np.median(Flux[BinMask])))

        BinnedPhase = np.asarray(BinnedPhase, dtype=float)
        BinnedFlux = np.asarray(BinnedFlux, dtype=float)
        if len(BinnedFlux) < 5:
            return Result

        PeakIndex = int(np.argmax(BinnedFlux))
        TroughIndex = int(np.argmin(BinnedFlux))
        PeakPhase = float(BinnedPhase[PeakIndex])
        TroughPhase = float(BinnedPhase[TroughIndex])

        RawDelta = abs(PeakPhase - TroughPhase)
        CyclicDelta = min(RawDelta, 1.0 - RawDelta)
        CyclicDiff = np.diff(np.r_[BinnedFlux, BinnedFlux[0]])

        Result.update({
            "PhaseCurveStd": float(np.std(BinnedFlux)),
            "PhaseCurveRange": float(np.max(BinnedFlux) - np.min(BinnedFlux)),
            "PhaseCurveSmoothness": float(np.std(CyclicDiff)),
            "PhasePeakPhase": PeakPhase,
            "PhaseTroughPhase": TroughPhase,
            "PhasePeakToTroughPhaseDelta": float(CyclicDelta),
        })

    except Exception as Exc:
        Logger.debug("Phase feature extraction failed: %s", Exc)

    return Result

# %% [markdown]
# # Per-Star Feature Extraction

# %%
def ExtractFeaturesForRow(Row: pd.Series, MetadataPath: Path) -> Dict[str, Any]:
    fitsBasePath = Path("/data/projects/TESS-research/data_pipeline")
    Result: Dict[str, Any] = {
        "FeatureStatus": "unknown",
        "FeatureError": None,
    }

    Result.update(ExtractIdentifierAndMetadataFeatures(Row))
    # LightCurvePath = ResolvePath(Row.get("lightCurvePath"), MetadataPath)
    LightCurvePath = Path(fitsBasePath / Row.get("lightCurvePath"))

    if LightCurvePath is None:
        Result["FeatureStatus"] = "missing_lightcurve_path"
        Result["FeatureError"] = "No lightCurvePath"
        return Result

    if not LightCurvePath.exists():
        Result["FeatureStatus"] = "missing_lightcurve_file"
        Result["FeatureError"] = str(LightCurvePath)
        return Result

    try:
        Time, Flux, FluxErr = LoadLightCurve(LightCurvePath)

        if len(Flux) < MinCadences:
            Result["FeatureStatus"] = "too_few_cadences"
            Result["FeatureError"] = f"Only {len(Flux)} finite cadences"
            Result["CadenceCount"] = float(len(Flux))
            return Result

        Result.update(ExtractBasicStatisticalFeatures(Time, Flux))
        Result.update(ExtractTailAsymmetryFeatures(Flux))
        Result.update(ExtractVariabilityFeatures(Time, Flux))

        LombScargleFeatures = ExtractLombScargleFeatures(Time, Flux, FluxErr)
        Result.update(LombScargleFeatures)

        BestPeriod = LombScargleFeatures.get("LsBestPeriod", np.nan)
        Result.update(ExtractPhaseFeatures(Time, Flux, BestPeriod))

        Result["FeatureStatus"] = "ok"

    except Exception as Exc:
        Result["FeatureStatus"] = "failed"
        Result["FeatureError"] = repr(Exc)

    return Result

# %% [markdown]
# # Dataset-Level Feature Extraction with Parallel Processing

# %%
def FinalizeFeatureDf(FeatureDf: pd.DataFrame) -> pd.DataFrame:
    if "_InputOrder" in FeatureDf.columns:
        FeatureDf = FeatureDf.sort_values("_InputOrder").drop(columns=["_InputOrder"]).reset_index(drop=True)
    return FeatureDf


def ExtractFeaturesSerial(MetadataDf: pd.DataFrame, MetadataPath: Path) -> pd.DataFrame:
    ResultRows = []
    for Position, (_, Row) in enumerate(MetadataDf.iterrows()):
        if Position % 100 == 0:
            Logger.info("Processing %s/%s", Position, len(MetadataDf))
        FeatureRow = ExtractFeaturesForRow(Row, MetadataPath)
        FeatureRow["_InputOrder"] = Position
        ResultRows.append(FeatureRow)
    return FinalizeFeatureDf(pd.DataFrame(ResultRows))


def ExtractFeaturesParallel(MetadataDf: pd.DataFrame, MetadataPath: Path, WorkerCount: int = WorkerCount) -> pd.DataFrame:
    ResultRows = []
    TotalRows = len(MetadataDf)
    Logger.info("Starting parallel feature extraction with WorkerCount=%s", WorkerCount)

    with ThreadPoolExecutor(max_workers=WorkerCount) as Executor:
        FutureMap = {}
        for Position, (_, Row) in enumerate(MetadataDf.iterrows()):
            Future = Executor.submit(ExtractFeaturesForRow, Row, MetadataPath)
            FutureMap[Future] = Position

        CompletedCount = 0
        for Future in as_completed(FutureMap):
            Position = FutureMap[Future]
            try:
                FeatureRow = Future.result()
            except Exception as Exc:
                FeatureRow = {"FeatureStatus": "failed", "FeatureError": repr(Exc)}

            FeatureRow["_InputOrder"] = Position
            ResultRows.append(FeatureRow)
            CompletedCount += 1

            if CompletedCount % 100 == 0 or CompletedCount == TotalRows:
                Logger.info("Completed %s/%s", CompletedCount, TotalRows)

    return FinalizeFeatureDf(pd.DataFrame(ResultRows))


def ExtractFeatures(MetadataDf: pd.DataFrame, MetadataPath: Path, WorkerCount: int = WorkerCount) -> pd.DataFrame:
    if WorkerCount <= 1:
        return ExtractFeaturesSerial(MetadataDf, MetadataPath)
    return ExtractFeaturesParallel(MetadataDf, MetadataPath, WorkerCount=WorkerCount)

# %% [markdown]
# # Execute Feature Extraction

# %%
MetadataDf = pd.read_parquet(InputMetadataPath)

FeatureDf = ExtractFeatures(
    MetadataDf=MetadataDf,
    MetadataPath=InputMetadataPath,
    WorkerCount=WorkerCount,
)

OutputFeaturePath.parent.mkdir(parents=True, exist_ok=True)
FeatureDf.to_parquet(OutputFeaturePath, index=False)

print(f"Saved {len(FeatureDf)} rows and {len(FeatureDf.columns)} columns to {OutputFeaturePath}")
FeatureDf["FeatureStatus"].value_counts(dropna=False)
# Out:
# 2026-08-02 16:22:37,701 INFO:FeatureExtractorNotebook:Starting parallel feature extraction with WorkerCount=16
# 0% (0/12767) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:37,955 INFO:lightkurve.utils:0% (0/12767) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/18678) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:37,981 INFO:lightkurve.utils:0% (0/18678) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28154) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:37,985 INFO:lightkurve.utils:0% (0/28154) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/47803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:38,033 INFO:lightkurve.utils:0% (0/47803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/53566) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:38,045 INFO:lightkurve.utils:0% (0/53566) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/26793) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:38,101 INFO:lightkurve.utils:0% (0/26793) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:38,123 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/40096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:38,132 INFO:lightkurve.utils:0% (0/40096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32158) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:38,147 INFO:lightkurve.utils:0% (0/32158) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/36973) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:38,147 INFO:lightkurve.utils:0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/281759) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:38,226 INFO:lightkurve.utils:0% (0/36973) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:38,246 INFO:lightkurve.utils:0% (0/281759) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25041) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:39,886 INFO:lightkurve.utils:0% (0/25041) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/3011) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:40,247 INFO:lightkurve.utils:0% (0/3011) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/26486) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:40,464 INFO:lightkurve.utils:0% (0/26486) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:41,359 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/35355) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:42,322 INFO:lightkurve.utils:0% (0/35355) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/10828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:42,417 INFO:lightkurve.utils:0% (0/10828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:42,708 INFO:lightkurve.utils:0% (0/23270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:42,843 INFO:lightkurve.utils:0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14258) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:43,101 INFO:lightkurve.utils:0% (0/14258) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/254238) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:43,102 INFO:lightkurve.utils:0% (0/254238) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:44,135 INFO:lightkurve.utils:0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17196) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:44,498 INFO:lightkurve.utils:0% (0/17196) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:44,624 INFO:lightkurve.utils:0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/75851) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:44,754 INFO:lightkurve.utils:0% (0/75851) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:44,920 INFO:lightkurve.utils:0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:45,433 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/18975) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:45,450 INFO:lightkurve.utils:0% (0/18975) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/291089) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:45,877 INFO:lightkurve.utils:0% (0/291089) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13339) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:46,241 INFO:lightkurve.utils:0% (0/13339) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14655) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:46,382 INFO:lightkurve.utils:0% (0/14655) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/41364) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:46,741 INFO:lightkurve.utils:0% (0/41364) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/27265) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:46,960 INFO:lightkurve.utils:0% (0/27265) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/53331) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:47,126 INFO:lightkurve.utils:0% (0/53331) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/2843) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:47,340 INFO:lightkurve.utils:0% (0/2843) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17598) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:47,702 INFO:lightkurve.utils:0% (0/17598) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/16167) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:47,946 INFO:lightkurve.utils:0% (0/16167) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:48,114 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14785) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:48,371 INFO:lightkurve.utils:0% (0/14785) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:48,607 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25143) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:48,719 INFO:lightkurve.utils:0% (0/25143) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:48,937 INFO:lightkurve.utils:0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:49,474 INFO:lightkurve.utils:0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4458) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:49,841 INFO:lightkurve.utils:0% (0/4458) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52376) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:49,895 INFO:lightkurve.utils:0% (0/52376) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:50,089 INFO:lightkurve.utils:0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/20736) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:50,677 INFO:lightkurve.utils:0% (0/20736) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:50,940 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32102) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:50,983 INFO:lightkurve.utils:0% (0/32102) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/42271) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:51,844 INFO:lightkurve.utils:0% (0/42271) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/271390) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:51,852 INFO:lightkurve.utils:0% (0/271390) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32315) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:52,485 INFO:lightkurve.utils:0% (0/32315) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13317) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:52,553 INFO:lightkurve.utils:0% (0/13317) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/35132) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:52,980 INFO:lightkurve.utils:0% (0/35132) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4942) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:52,988 INFO:lightkurve.utils:0% (0/4942) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23075) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:53,139 INFO:lightkurve.utils:0% (0/23075) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/58244) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:53,413 INFO:lightkurve.utils:0% (0/58244) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/9058) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:53,618 INFO:lightkurve.utils:0% (0/9058) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/39085) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:54,079 INFO:lightkurve.utils:0% (0/39085) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/46263) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:54,190 INFO:lightkurve.utils:0% (0/46263) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19468) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:54,424 INFO:lightkurve.utils:0% (0/19468) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11948) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:55,130 INFO:lightkurve.utils:0% (0/11948) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:55,423 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23099) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:55,578 INFO:lightkurve.utils:0% (0/23099) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/254238) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:55,808 INFO:lightkurve.utils:0% (0/254238) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/58278) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:56,344 INFO:lightkurve.utils:0% (0/58278) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14055) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:56,413 INFO:lightkurve.utils:0% (0/14055) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24254) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:56,732 INFO:lightkurve.utils:0% (0/24254) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:57,313 INFO:lightkurve.utils:0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/64915) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/37793) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:57,332 INFO:lightkurve.utils:0% (0/64915) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:57,339 INFO:lightkurve.utils:0% (0/37793) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/20498) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:57,887 INFO:lightkurve.utils:0% (0/20498) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/21346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:57,941 INFO:lightkurve.utils:0% (0/21346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43291) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:58,671 INFO:lightkurve.utils:0% (0/43291) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/276410) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:58,716 INFO:lightkurve.utils:0% (0/276410) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:58,810 INFO:lightkurve.utils:0% (0/32101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/47803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:58,836 INFO:lightkurve.utils:0% (0/47803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/53831) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:58,905 INFO:lightkurve.utils:0% (0/53831) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19881) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:58,998 INFO:lightkurve.utils:0% (0/19881) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/33867) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:22:59,796 INFO:lightkurve.utils:0% (0/33867) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:00,266 INFO:lightkurve.utils:0% (0/22096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24319) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:00,458 INFO:lightkurve.utils:0% (0/24319) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25138) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:00,714 INFO:lightkurve.utils:0% (0/25138) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/57998) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:00,981 INFO:lightkurve.utils:0% (0/57998) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4017) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:01,225 INFO:lightkurve.utils:0% (0/4017) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14367) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:01,305 INFO:lightkurve.utils:0% (0/14367) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4449) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:01,444 INFO:lightkurve.utils:0% (0/4449) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24829) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:02,193 INFO:lightkurve.utils:0% (0/24829) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:02,968 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/42450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:03,148 INFO:lightkurve.utils:0% (0/42450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/88826) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:03,185 INFO:lightkurve.utils:0% (0/88826) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:03,654 INFO:FeatureExtractorNotebook:Completed 100/7294
# 0% (0/19768) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:04,091 INFO:lightkurve.utils:0% (0/19768) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/62270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:04,404 INFO:lightkurve.utils:0% (0/62270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:04,406 INFO:lightkurve.utils:0% (0/23270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/67641) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:04,529 INFO:lightkurve.utils:0% (0/67641) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/36180) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:04,692 INFO:lightkurve.utils:0% (0/36180) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11473) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:04,956 INFO:lightkurve.utils:0% (0/11473) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:05,221 INFO:lightkurve.utils:0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/16987) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:05,272 INFO:lightkurve.utils:0% (0/16987) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:05,281 INFO:lightkurve.utils:0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11065) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:05,900 INFO:lightkurve.utils:0% (0/11065) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/18851) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:06,116 INFO:lightkurve.utils:0% (0/18851) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/53615) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:06,640 INFO:lightkurve.utils:0% (0/53615) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/291333) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:06,869 INFO:lightkurve.utils:0% (0/291333) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13308) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:07,112 INFO:lightkurve.utils:0% (0/13308) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:08,134 INFO:lightkurve.utils:0% (0/19450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/44861) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:08,239 INFO:lightkurve.utils:0% (0/44861) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17144) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:08,672 INFO:lightkurve.utils:0% (0/17144) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13442) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:09,059 INFO:lightkurve.utils:0% (0/13442) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/7935) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:09,178 INFO:lightkurve.utils:0% (0/7935) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13482) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:09,908 INFO:lightkurve.utils:0% (0/13482) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:10,380 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25806) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:10,395 INFO:lightkurve.utils:0% (0/25806) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/10399) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:10,823 INFO:lightkurve.utils:0% (0/10399) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23416) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:10,921 INFO:lightkurve.utils:0% (0/23416) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:11,480 INFO:lightkurve.utils:0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:11,530 INFO:lightkurve.utils:0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/66298) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:11,703 INFO:lightkurve.utils:0% (0/66298) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/64915) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:11,951 INFO:lightkurve.utils:0% (0/64915) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4478) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:12,137 INFO:lightkurve.utils:0% (0/4478) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:12,151 INFO:lightkurve.utils:0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:12,337 INFO:lightkurve.utils:0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17013) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:12,354 INFO:lightkurve.utils:0% (0/17013) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/29810) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:12,954 INFO:lightkurve.utils:0% (0/29810) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/27796) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:13,398 INFO:lightkurve.utils:0% (0/27796) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/291101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:13,618 INFO:lightkurve.utils:0% (0/291101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32123) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:14,258 INFO:lightkurve.utils:0% (0/32123) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/97313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:14,759 INFO:lightkurve.utils:0% (0/97313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4942) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:15,021 INFO:lightkurve.utils:0% (0/4942) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/54024) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:15,049 INFO:lightkurve.utils:0% (0/54024) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17517) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:15,074 INFO:lightkurve.utils:0% (0/17517) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/44933) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:15,113 INFO:lightkurve.utils:0% (0/44933) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17222) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:15,434 INFO:lightkurve.utils:0% (0/17222) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11608) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:15,958 INFO:lightkurve.utils:0% (0/11608) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/2926) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:16,118 INFO:lightkurve.utils:0% (0/2926) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/45095) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:16,537 INFO:lightkurve.utils:0% (0/45095) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:16,690 INFO:lightkurve.utils:0% (0/19803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/10828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:17,417 INFO:lightkurve.utils:0% (0/10828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/34934) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:17,420 INFO:lightkurve.utils:0% (0/34934) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/42450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:17,435 INFO:lightkurve.utils:0% (0/42450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13392) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:17,454 INFO:lightkurve.utils:0% (0/13392) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/58278) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:17,877 INFO:lightkurve.utils:0% (0/58278) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22228) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:18,120 INFO:lightkurve.utils:0% (0/22228) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:18,739 INFO:lightkurve.utils:0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4615) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:18,767 INFO:lightkurve.utils:0% (0/4615) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/26809) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:18,930 INFO:lightkurve.utils:0% (0/26809) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:19,258 INFO:lightkurve.utils:0% (0/11346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28823) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:19,626 INFO:lightkurve.utils:0% (0/28823) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52480) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:19,918 INFO:lightkurve.utils:0% (0/52480) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23656) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:19,920 INFO:lightkurve.utils:0% (0/23656) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32144) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:19,941 INFO:lightkurve.utils:0% (0/32144) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/15627) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:20,036 INFO:lightkurve.utils:0% (0/15627) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19527) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:20,319 INFO:lightkurve.utils:0% (0/19527) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/287970) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:20,457 INFO:lightkurve.utils:0% (0/287970) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/48812) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:20,985 INFO:lightkurve.utils:0% (0/48812) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:21,134 INFO:lightkurve.utils:0% (0/19450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4765) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:21,242 INFO:lightkurve.utils:0% (0/4765) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/2424) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:21,570 INFO:lightkurve.utils:0% (0/2424) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:21,658 INFO:lightkurve.utils:0% (0/24638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/56983) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:21,666 INFO:lightkurve.utils:0% (0/56983) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24829) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:22,103 INFO:lightkurve.utils:0% (0/24829) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:22,205 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/15212) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:22,981 INFO:lightkurve.utils:0% (0/15212) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/34526) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:23,373 INFO:lightkurve.utils:0% (0/34526) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24782) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:23,574 INFO:lightkurve.utils:0% (0/24782) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:24,407 INFO:lightkurve.utils:0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11033) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:24,670 INFO:lightkurve.utils:0% (0/11033) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/80991) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:24,773 INFO:lightkurve.utils:0% (0/80991) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14498) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:25,043 INFO:lightkurve.utils:0% (0/14498) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:25,347 INFO:FeatureExtractorNotebook:Completed 200/7294
# 0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:25,648 INFO:lightkurve.utils:0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/64979) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:25,662 INFO:lightkurve.utils:0% (0/64979) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25423) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:25,817 INFO:lightkurve.utils:0% (0/25423) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/31267) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:26,363 INFO:lightkurve.utils:0% (0/31267) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:26,743 INFO:lightkurve.utils:0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:26,855 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/294782) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:27,294 INFO:lightkurve.utils:0% (0/294782) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43021) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:28,224 INFO:lightkurve.utils:0% (0/43021) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/37201) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:28,480 INFO:lightkurve.utils:0% (0/37201) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4934) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:29,217 INFO:lightkurve.utils:0% (0/4934) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/57027) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:29,615 INFO:lightkurve.utils:0% (0/57027) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4116) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:30,277 INFO:lightkurve.utils:0% (0/4116) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:30,672 INFO:lightkurve.utils:0% (0/19803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/10399) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:31,258 INFO:lightkurve.utils:0% (0/10399) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/33421) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/41338) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:31,272 INFO:lightkurve.utils:0% (0/33421) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:31,298 INFO:lightkurve.utils:0% (0/41338) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/47010) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:32,291 INFO:lightkurve.utils:0% (0/47010) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14963) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:32,549 INFO:lightkurve.utils:0% (0/14963) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/71479) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:32,711 INFO:lightkurve.utils:0% (0/71479) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22228) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:32,940 INFO:lightkurve.utils:0% (0/22228) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:33,140 INFO:lightkurve.utils:0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28159) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:33,301 INFO:lightkurve.utils:0% (0/28159) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:33,411 INFO:lightkurve.utils:0% (0/11346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4462) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:33,731 INFO:lightkurve.utils:0% (0/4462) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:34,143 INFO:lightkurve.utils:0% (0/32101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14611) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:34,952 INFO:lightkurve.utils:0% (0/14611) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/40096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:35,441 INFO:lightkurve.utils:0% (0/40096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/46681) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:35,683 INFO:lightkurve.utils:0% (0/46681) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24223) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/57828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:35,690 INFO:lightkurve.utils:0% (0/24223) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:35,696 INFO:lightkurve.utils:0% (0/57828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/2464) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:35,926 INFO:lightkurve.utils:0% (0/2464) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25325) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:36,330 INFO:lightkurve.utils:0% (0/25325) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/9060) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:36,460 INFO:lightkurve.utils:0% (0/9060) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11234) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:23:36,826 INFO:lightkurve.utils:0% (0/11234) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# ...
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:35,843 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:36,354 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:36,354 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:36,358 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:36,532 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:36,951 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:37,026 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:38,265 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:38,423 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:38,675 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:40,634 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:40,893 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:41,435 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:42,156 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:42,172 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:42,701 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:42,706 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:42,922 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:42,970 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:43,125 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:43,752 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/15568) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:43,943 INFO:lightkurve.utils:0% (0/15568) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:44,160 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:44,165 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:44,322 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:44,659 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:46,529 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:46,883 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:47,284 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:47,604 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:48,144 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:48,507 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:49,090 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:49,374 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:49,601 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:50,008 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:50,019 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:50,400 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:50,908 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:51,531 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:51,924 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:51,994 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:52,720 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:53,558 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:53,943 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:54,181 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:54,613 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:54,912 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:55,133 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:55,189 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:57,018 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25049) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:57,914 INFO:lightkurve.utils:0% (0/25049) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:57,996 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:58,657 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:58,676 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:58,948 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:59,168 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:52:59,682 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:53:00,080 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:53:00,279 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:53:00,529 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25049) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:53:00,825 INFO:lightkurve.utils:0% (0/25049) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:53:01,218 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:53:01,223 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:53:02,618 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:53:03,076 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:53:03,663 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-08-02 16:53:06,396 INFO:FeatureExtractorNotebook:Completed 7294/7294
# Saved 7294 rows and 59 columns to /data/projects/TESS-research/feature_extraction/TESS_features.parquet
# FeatureStatus
# ok                  7281
# failed                11
# too_few_cadences       2
# Name: count, dtype: int64

# %% [markdown]
# # Quick Sanity Checks

# %%
display(FeatureDf.head())

NumericColumns = FeatureDf.select_dtypes(include=[np.number]).columns
MissingRate = FeatureDf[NumericColumns].isna().mean().sort_values(ascending=False)
display(MissingRate.head(30))
# Out:
#   FeatureStatus FeatureError   family VSXType                         VSXId  \
# 0            ok          NaN  CEPHEID   DCEPS  Gaia DR3 4685823446113073792
# 1            ok          NaN  CEPHEID     CWB  ASASSN-V J001916.11-180430.8
# 2            ok          NaN  CEPHEID     CWB          CSS_J014935.9+141132
# 3            ok          NaN  CEPHEID    DCEP   Gaia DR3 461049865760507904
# 4            ok          NaN  CEPHEID   DCEPS  Gaia DR3 4662956971490538880
#
#                                       lightCurvePath  \
# 0  /data/projects/TESS-research/data_pipeline/TES...
# 1  /data/projects/TESS-research/data_pipeline/TES...
# 2  /data/projects/TESS-research/data_pipeline/TES...
# 3  /data/projects/TESS-research/data_pipeline/TES...
# 4  /data/projects/TESS-research/data_pipeline/TES...
#
#                                    rawLightCurvePath QualityLabel  \
# 0  /data/projects/TESS-research/data_pipeline/TES...        clean
# 1  /data/projects/TESS-research/data_pipeline/TES...        clean
# 2  /data/projects/TESS-research/data_pipeline/TES...        clean
# 3  /data/projects/TESS-research/data_pipeline/TES...        clean
# 4  /data/projects/TESS-research/data_pipeline/TES...        clean
#
#    QualityScore Provenance  ...  LsPowerRatio21  LsPowerRatio31  \
# 0           0.0    TESSCut  ...        0.965596        0.962654
# 1           0.0    TESSCut  ...        0.991554        0.989106
# 2           0.0    TESSCut  ...        0.988269        0.981074
# 3           0.0        QLP  ...        0.977464        0.976398
# 4           0.0    TESSCut  ...        0.990783        0.915923
#
#    LsPeriodRatio21  LsPeriodRatio31 PhaseCurveStd PhaseCurveRange  \
# 0         1.000523         0.999478      0.108526        0.363780
# 1         1.012854         0.987469      0.160734        0.640752
# 2         1.019496         0.981236      0.346630        1.472735
# 3         0.999790         1.000210      0.073633        0.217096
# 4         1.000500         0.999501      0.034486        0.119370
#
#    PhaseCurveSmoothness  PhasePeakPhase  PhaseTroughPhase  \
# 0              0.089044        0.625510          0.974632
# 1              0.156908        0.787201          0.077085
# 2              0.332614        0.026434          0.275024
# 3              0.025917        0.775062          0.475095
# 4              0.021449        0.675007          0.325098
#
#    PhasePeakToTroughPhaseDelta
# 0                     0.349122
# 1                     0.289884
# 2                     0.248590
# 3                     0.299967
# 4                     0.349909
#
# [5 rows x 59 columns]
# TimeSpanDays                  0.001782
# MedianCadenceDays             0.001782
# FluxP90                       0.001782
# FluxP10                       0.001782
# FluxP05                       0.001782
# FluxMad                       0.001782
# FluxMedian                    0.001782
# FluxStd                       0.001782
# FluxP95                       0.001782
# FluxIqr                       0.001782
# TailUpper                     0.001782
# FluxKurtosis                  0.001782
# FluxSkewness                  0.001782
# FluxPercentAmplitude90To10    0.001782
# FluxPercentAmplitude95To5     0.001782
# FluxAmplitude                 0.001782
# LsMaxPower                    0.001782
# LsFalseAlarmProbability       0.001782
# LsPeriod2                     0.001782
# LsPeriod3                     0.001782
# LsPower2                      0.001782
# LsPower3                      0.001782
# TailLower                     0.001782
# TailAsymmetry                 0.001782
# TailRatio                     0.001782
# EtaVonNeumann                 0.001782
# MaxAbsSlope                   0.001782
# MedianAbsSuccessiveDiff       0.001782
# FractionBeyond1Std            0.001782
# FractionBeyond2Std            0.001782
# dtype: float64

# %%
if "family" in FeatureDf.columns:
    display(pd.crosstab(FeatureDf["family"], FeatureDf["FeatureStatus"], dropna=False))
# Out:
# FeatureStatus    failed   ok  too_few_cadences
# family
# CEPHEID               0  962                 1
# CV                    0  516                 0
# DSCT_SXPHE            0  968                 0
# ECLIPSING             0  956                 0
# ELLIPSOIDAL_ROT       0  982                 0
# LONG_PERIOD           0  959                 0
# RRLYR                 0  917                 0
# XRAY                  0   51                 0
# YSO                   0  970                 1
# NaN                  11    0                 0
