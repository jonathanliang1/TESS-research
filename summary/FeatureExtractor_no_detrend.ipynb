# %% [markdown]
# # Feature Extraction for VSX → TESS Variable-Star Classification
#
# This notebook extracts interpretable machine-learning features from standardized TESS light-curve FITS files.
#
# It is designed for the current research pipeline:
#
# - **Input**: metadata parquet containing `lightCurvePath`
# - **Light curve source**: standardized FITS files already saved by `TessDataDownloader.py`
# - **Output**: feature parquet, one row per star
# - **Parallel processing**: configurable thread pool, default `WorkerCount = 16`
#
# Important leakage rule:
#
# > Feature extraction here is safe before train/validation/test split because every feature is computed independently per star.
# > Dataset-level scaling, PCA, feature selection, and model fitting must happen only after train/validation/test split.

# %% [markdown]
# # Complete Feature List
#
# ## 1. Identification / Metadata Features
#
# | Feature | Meaning | Method / Source |
# |---|---|---|
# | `family` | VSX family label, e.g. `RRLYR`, `CEPHEID`, `ECLIPSING` | copied from metadata |
# | `VSXType` | Original/mapped VSX type | copied from metadata |
# | `VSXId` | VSX identifier | copied from metadata |
# | `Name` | VSX object name | copied from metadata |
# | `ticId` | TIC identifier, if present | copied from metadata |
# | `bestTicId` | selected TIC match | copied from metadata |
# | `ticDistanceArcmin` | angular distance to selected TIC match | copied from metadata |
# | `lightCurvePath` | standardized FITS path | copied from metadata |
# | `rawLightCurvePath` | raw FITS path | copied from metadata |
# | `trendFlag` | trend flag from trend analysis, if present | copied from metadata |
# | `trendScore` | trend score, if present | copied from metadata |
# | `adfPValue` | stationarity metric, if present | copied from metadata |
# | `QualityLabel` | light curve quality label | copied/inferred from metadata |
# | `QualityScore` | numeric quality encoding | clean=0, acceptable=1, caution=2, poor=3 |
# | `Provenance` | data source: SPOC / QLP / TESSCut | copied/inferred from metadata |
# | `ProvenanceScore` | numeric provenance encoding | SPOC=0, QLP=1, TESSCut=2 |
# | `OriginalFluxMedian` | original pre-standardization median flux | copied from metadata |
# | `OriginalFluxStd` | original pre-standardization flux std | copied from metadata |
# | `OriginalFluxSnr` | original flux signal-to-noise estimate | copied from metadata |
# | `LowSnr` | low-SNR flag | copied from metadata |
# | `LowQualityLightCurve` | low-quality light curve flag | copied from metadata |
#
# ## 2. Data Coverage / Cadence Features
#
# | Feature | Meaning | Method |
# |---|---|---|
# | `CadenceCount` | number of finite flux observations | `len(Flux)` |
# | `TimeSpanDays` | total time baseline | `max(Time) - min(Time)` |
# | `MedianCadenceDays` | typical time spacing between observations | `median(diff(Time))` |
#
# ## 3. Flux Distribution Features
#
# | Feature | Meaning | Method |
# |---|---|---|
# | `FluxMean` | average standardized brightness | `mean(Flux)` |
# | `FluxStd` | standard deviation of brightness | `std(Flux)` |
# | `FluxVariance` | variance of brightness | `var(Flux)` |
# | `FluxMedian` | median brightness | `median(Flux)` |
# | `FluxMad` | robust variability measure | `median(abs(Flux - median))` |
# | `FluxMin` | minimum flux | `min(Flux)` |
# | `FluxMax` | maximum flux | `max(Flux)` |
# | `FluxP01` | 1st percentile | `percentile(Flux, 1)` |
# | `FluxP05` | 5th percentile | `percentile(Flux, 5)` |
# | `FluxP10` | 10th percentile | `percentile(Flux, 10)` |
# | `FluxP25` | 25th percentile | `percentile(Flux, 25)` |
# | `FluxP75` | 75th percentile | `percentile(Flux, 75)` |
# | `FluxP90` | 90th percentile | `percentile(Flux, 90)` |
# | `FluxP95` | 95th percentile | `percentile(Flux, 95)` |
# | `FluxP99` | 99th percentile | `percentile(Flux, 99)` |
# | `FluxIqr` | robust middle spread | `P75 - P25` |
# | `FluxAmplitude` | full observed flux range | `max(Flux) - min(Flux)` |
# | `FluxPercentAmplitude95To5` | robust amplitude | `P95 - P05` |
# | `FluxPercentAmplitude90To10` | more conservative robust amplitude | `P90 - P10` |
# | `FluxSkewness` | asymmetry of flux distribution | `scipy.stats.skew(Flux)` |
# | `FluxKurtosis` | peakedness / heavy-tail behavior | `scipy.stats.kurtosis(Flux)` |
#
# ## 4. Tail-Asymmetry Features
#
# These features are intended to distinguish upward spikes from downward dips.
#
# | Feature | Meaning | Method |
# |---|---|---|
# | `TailUpper` | strength of upper-brightness tail | `P95 - P50` |
# | `TailLower` | strength of lower-brightness tail | `P50 - P05` |
# | `TailAsymmetry` | positive = upper spikes dominate; negative = dips dominate | `TailUpper - TailLower` |
# | `TailRatio` | ratio of upper-tail to lower-tail strength | `TailUpper / (TailLower + eps)` |
#
# ## 5. Time-Domain Variability Features
#
# | Feature | Meaning | Method |
# |---|---|---|
# | `EtaVonNeumann` | smoothness / serial-correlation proxy | `sum(diff(Flux)^2) / ((N-1) * var(Flux))` |
# | `MaxAbsSlope` | largest brightness change rate | `max(abs(diff(Flux) / diff(Time)))` |
# | `MedianAbsSuccessiveDiff` | typical point-to-point brightness change | `median(abs(diff(Flux)))` |
# | `FractionBeyond1Std` | fraction farther than 1 std from mean | `mean(abs(Flux - mean) > std)` |
# | `FractionBeyond2Std` | fraction farther than 2 std from mean | `mean(abs(Flux - mean) > 2*std)` |
#
# ## 6. Lomb-Scargle Period Features
#
# | Feature | Meaning | Method |
# |---|---|---|
# | `LsBestPeriod` | dominant period in days | `1 / frequency[argmax(power)]` |
# | `LsBestFrequency` | dominant frequency | `frequency[argmax(power)]` |
# | `LsMaxPower` | strength of dominant periodic signal | `max(power)` |
# | `LsFalseAlarmProbability` | chance probability of dominant periodogram peak | `false_alarm_probability(maxPower)` |
# | `LsPeriod2` | second strongest period | second-highest periodogram peak |
# | `LsPeriod3` | third strongest period | third-highest periodogram peak |
# | `LsPower2` | second strongest peak power | second-highest power |
# | `LsPower3` | third strongest peak power | third-highest power |
# | `LsPowerRatio21` | second/first power ratio | `Power2 / Power1` |
# | `LsPowerRatio31` | third/first power ratio | `Power3 / Power1` |
# | `LsPeriodRatio21` | second/first period ratio | `Period2 / Period1` |
# | `LsPeriodRatio31` | third/first period ratio | `Period3 / Period1` |
#
# ## 7. Phase-Folded Morphology Features
#
# | Feature | Meaning | Method |
# |---|---|---|
# | `PhaseCurveStd` | scatter of binned phase curve | `std(binnedFlux)` |
# | `PhaseCurveRange` | amplitude of binned phase curve | `max(binnedFlux) - min(binnedFlux)` |
# | `PhaseCurveSmoothness` | jaggedness/smoothness of folded curve | `std(diff(cyclicBinnedFlux))` |
# | `PhasePeakPhase` | phase location of maximum binned flux | `phase[argmax(binnedFlux)]` |
# | `PhaseTroughPhase` | phase location of minimum binned flux | `phase[argmin(binnedFlux)]` |
# | `PhasePeakToTroughPhaseDelta` | cyclic phase distance from peak to trough | `min(abs(delta), 1 - abs(delta))` |
#
# ## 8. Extraction Status Features
#
# | Feature | Meaning | Method / Source |
# |---|---|---|
# | `FeatureStatus` | extraction result: ok / failed / missing file / too few cadences | generated by extractor |
# | `FeatureError` | error message if extraction failed | generated by extractor |

# %% [markdown]
# # Imports and Configuration

# %%
from __future__ import annotations

import logging
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path
from typing import Any, Dict, Optional, Tuple

import numpy as np
import pandas as pd

import lightkurve as lk
from astropy.io import fits
from astropy.timeseries import LombScargle
from scipy.stats import skew, kurtosis

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s:%(name)s:%(message)s",
)

Logger = logging.getLogger("FeatureExtractorNotebook")

# Update these paths for your local repo.
# InputMetadataPath = Path("../trend_detection/TESSAugmented_QC_trend.parquet")
InputMetadataPath = Path("/data/projects/TESS-research/data_pipeline/TESSCache/TESSAugmented_QC.parquet")
OutputFeaturePath = Path("/data/projects/TESS-research/feature_extraction/TESS_features.parquet")
# InputMetadataPath = Path("/data/projects/TESS-research/detrend_tesscut/output/TESSAugmented_QC_tesscut_conditional_detrended.parquet")
# OutputFeaturePath = Path("TESS_conditional_detrended_features.parquet")

MinPeriodDays = 0.05
MaxPeriodDays = 100.0
SamplesPerPeak = 10
MinCadences = 100
PhaseBinCount = 20
WorkerCount = 16
Eps = 1e-12

QualityScoreMap = {
    "clean": 0,
    "acceptable": 1,
    "caution": 2,
    "poor": 3,
    "missing": 4,
}

ProvenanceScoreMap = {
    "SPOC": 0,
    "QLP": 1,
    "TESSCut": 2,
}

# %% [markdown]
# # Utility Functions

# %%
def SafeFloat(Value: Any) -> float:
    try:
        FloatValue = float(Value)
    except Exception:
        return np.nan
    return FloatValue if np.isfinite(FloatValue) else np.nan


def SafeBool(Value: Any) -> bool:
    if Value is None:
        return False
    if isinstance(Value, float) and pd.isna(Value):
        return False
    return bool(Value)


def SafeDivide(Numerator: float, Denominator: float, Eps: float = Eps) -> float:
    if not np.isfinite(Numerator) or not np.isfinite(Denominator) or abs(Denominator) < Eps:
        return np.nan
    return float(Numerator / Denominator)


def ResolvePath(PathValue: Any, MetadataPath: Path) -> Optional[Path]:
    if PathValue is None:
        return None
    if isinstance(PathValue, float) and pd.isna(PathValue):
        return None

    PathObj = Path(str(PathValue))
    if PathObj.is_absolute() and PathObj.exists():
        return PathObj
    if PathObj.exists():
        return PathObj

    CandidatePath = MetadataPath.parent / PathObj
    if CandidatePath.exists():
        return CandidatePath

    return PathObj

# %% [markdown]
# # Light Curve Loading

# %%
def LoadLightCurve(LightCurvePath: Path) -> Tuple[np.ndarray, np.ndarray, Optional[np.ndarray]]:
    """Load a light curve while treating flux uncertainty as optional.

    Time and flux determine whether a cadence is scientifically usable.
    FluxErr is retained only when it is aligned with the loaded arrays and all
    retained uncertainty values are finite and strictly positive. Invalid or
    missing uncertainty therefore downgrades Lomb-Scargle from weighted to
    unweighted analysis instead of removing otherwise valid QLP cadences.
    """

    def FirstAvailableColumn(ColumnNames: list[str], CandidateNames: list[str]) -> Optional[str]:
        NameMap = {Name.upper(): Name for Name in ColumnNames}
        for CandidateName in CandidateNames:
            MatchedName = NameMap.get(CandidateName.upper())
            if MatchedName is not None:
                return MatchedName
        return None

    def ReadGenericFitsTable(FitsPath: Path) -> Tuple[np.ndarray, np.ndarray, Optional[np.ndarray]]:
        with fits.open(str(FitsPath), memmap=False) as Hdul:
            TableData = None

            for Hdu in Hdul:
                Data = getattr(Hdu, "data", None)
                if Data is not None and getattr(Data, "dtype", None) is not None and Data.dtype.names:
                    TableData = Data
                    break

            if TableData is None:
                raise ValueError("No FITS binary table with named columns was found")

            ColumnNames = list(TableData.dtype.names)

            TimeColumn = FirstAvailableColumn(
                ColumnNames,
                ["TIME", "TMID", "BJD"],
            )
            FluxColumn = FirstAvailableColumn(
                ColumnNames,
                ["FLUX", "SAP_FLUX", "PDCSAP_FLUX", "KSPSAP_FLUX", "DET_FLUX", "NORM_FLUX"],
            )
            FluxErrColumn = FirstAvailableColumn(
                ColumnNames,
                ["FLUX_ERR", "SAP_FLUX_ERR", "PDCSAP_FLUX_ERR", "KSPSAP_FLUX_ERR", "ERR_FLUX"],
            )

            if TimeColumn is None or FluxColumn is None:
                raise ValueError(
                    f"Required time/flux columns are missing. Available columns: {ColumnNames}"
                )

            Time = np.asarray(TableData[TimeColumn], dtype=float).reshape(-1)
            Flux = np.asarray(TableData[FluxColumn], dtype=float).reshape(-1)
            FluxErr = None

            if FluxErrColumn is not None:
                FluxErr = np.asarray(TableData[FluxErrColumn], dtype=float).reshape(-1)

            return Time, Flux, FluxErr

    def ExtractFromLightkurve(LightCurve) -> Tuple[np.ndarray, np.ndarray, Optional[np.ndarray]]:
        Time = np.asarray(
            getattr(LightCurve.time, "value", LightCurve.time),
            dtype=float,
        ).reshape(-1)

        Flux = np.asarray(
            getattr(LightCurve.flux, "value", LightCurve.flux),
            dtype=float,
        ).reshape(-1)

        FluxErr = None
        if hasattr(LightCurve, "flux_err") and LightCurve.flux_err is not None:
            FluxErr = np.asarray(
                getattr(LightCurve.flux_err, "value", LightCurve.flux_err),
                dtype=float,
            ).reshape(-1)

        return Time, Flux, FluxErr

    LightCurvePath = Path(LightCurvePath)

    if not LightCurvePath.exists():
        raise FileNotFoundError(str(LightCurvePath))

    Time = None
    Flux = None
    FluxErr = None
    ReadErrors = []

    # Attempt 1: standard lightkurve reader.
    try:
        LightCurve = lk.read(str(LightCurvePath))
        Time, Flux, FluxErr = ExtractFromLightkurve(LightCurve)
    except Exception as Exc:
        ReadErrors.append(f"generic lk.read: {Exc!r}")

    # Attempt 2: QLP-specific reader.
    if Time is None or Flux is None:
        try:
            LightCurve = lk.read(
                str(LightCurvePath),
                author="QLP",
                flux_column="kspsap_flux",
            )
            Time, Flux, FluxErr = ExtractFromLightkurve(LightCurve)
        except Exception as Exc:
            ReadErrors.append(f"QLP lk.read: {Exc!r}")

    # Attempt 3: direct FITS table parsing.
    if Time is None or Flux is None:
        try:
            Time, Flux, FluxErr = ReadGenericFitsTable(LightCurvePath)
        except Exception as Exc:
            ReadErrors.append(f"generic FITS parsing: {Exc!r}")
            raise ValueError(
                "Unable to read light curve. " + " | ".join(ReadErrors)
            ) from Exc

    if Time.shape != Flux.shape:
        raise ValueError(
            f"Time/Flux shape mismatch: Time={Time.shape}, Flux={Flux.shape}"
        )

    # Only Time and Flux define a valid cadence.
    CadenceMask = np.isfinite(Time) & np.isfinite(Flux)

    FilteredTime = Time[CadenceMask]
    FilteredFlux = Flux[CadenceMask]
    FilteredFluxErr = None

    # FluxErr is optional. It must never remove otherwise valid Time/Flux rows.
    if FluxErr is not None:
        if FluxErr.shape == Time.shape:
            CandidateFluxErr = FluxErr[CadenceMask]
            ValidFluxErr = np.isfinite(CandidateFluxErr) & (CandidateFluxErr > 0)

            if len(CandidateFluxErr) > 0 and np.all(ValidFluxErr):
                FilteredFluxErr = CandidateFluxErr
            else:
                Logger.debug(
                    "Ignoring unusable flux_err for %s: %d/%d retained values are finite and positive",
                    LightCurvePath,
                    int(np.sum(ValidFluxErr)),
                    len(CandidateFluxErr),
                )
        else:
            Logger.debug(
                "Ignoring flux_err shape mismatch for %s: flux_err=%s, time=%s",
                LightCurvePath,
                FluxErr.shape,
                Time.shape,
            )

    # Keep samples in chronological order.
    Order = np.argsort(FilteredTime)
    FilteredTime = FilteredTime[Order]
    FilteredFlux = FilteredFlux[Order]

    if FilteredFluxErr is not None:
        FilteredFluxErr = FilteredFluxErr[Order]

    return FilteredTime, FilteredFlux, FilteredFluxErr

# %% [markdown]
# # Identification and Metadata Features

# %%
def ExtractIdentifierAndMetadataFeatures(Row: pd.Series) -> Dict[str, Any]:
    Result: Dict[str, Any] = {}

    ColumnsToPreserve = [
        "family", "VSXType", "VSXId", "Name", "ticId", "bestTicId",
        "ticDistanceArcmin", "lightCurvePath", "rawLightCurvePath",
        "trendFlag", "trendScore", "adfPValue",
    ]

    for ColumnName in ColumnsToPreserve:
        if ColumnName in Row.index:
            Result[ColumnName] = Row.get(ColumnName)

    QualityValue = Row.get("quality", Row.get("fitsQcStatus", Row.get("lightCurveQuality", np.nan)))
    ProvenanceValue = Row.get("provenance", Row.get("author", np.nan))

    QualityLabel = str(QualityValue) if not pd.isna(QualityValue) else "missing"
    ProvenanceLabel = str(ProvenanceValue) if not pd.isna(ProvenanceValue) else "missing"

    Result.update({
        "QualityLabel": QualityLabel,
        "QualityScore": QualityScoreMap.get(QualityLabel, np.nan),
        "Provenance": ProvenanceLabel,
        "ProvenanceScore": ProvenanceScoreMap.get(ProvenanceLabel, np.nan),
        "OriginalFluxMedian": SafeFloat(Row.get("fluxMedian", np.nan)),
        "OriginalFluxStd": SafeFloat(Row.get("fluxStd", np.nan)),
        "OriginalFluxSnr": SafeFloat(Row.get("fluxSnr", np.nan)),
        "LowSnr": SafeBool(Row.get("lowSNR", False)),
        "LowQualityLightCurve": SafeBool(Row.get("lowQualityLightCurve", False)),
    })
    return Result

# %% [markdown]
# # Data Coverage and Flux Distribution Features

# %%
def ExtractBasicStatisticalFeatures(Time: np.ndarray, Flux: np.ndarray) -> Dict[str, float]:
    CadenceCount = len(Flux)
    P01, P05, P10, P25, P50, P75, P90, P95, P99 = np.percentile(
        Flux, [1, 5, 10, 25, 50, 75, 90, 95, 99]
    )
    FluxStd = float(np.std(Flux))

    return {
        "CadenceCount": float(CadenceCount),
        "TimeSpanDays": float(np.max(Time) - np.min(Time)) if CadenceCount > 1 else np.nan,
        "MedianCadenceDays": float(np.median(np.diff(Time))) if CadenceCount > 2 else np.nan,
        "FluxMean": float(np.mean(Flux)),
        "FluxStd": FluxStd,
        "FluxVariance": float(np.var(Flux)),
        "FluxMedian": float(P50),
        "FluxMad": float(np.median(np.abs(Flux - P50))),
        "FluxMin": float(np.min(Flux)),
        "FluxMax": float(np.max(Flux)),
        "FluxP01": float(P01),
        "FluxP05": float(P05),
        "FluxP10": float(P10),
        "FluxP25": float(P25),
        "FluxP75": float(P75),
        "FluxP90": float(P90),
        "FluxP95": float(P95),
        "FluxP99": float(P99),
        "FluxIqr": float(P75 - P25),
        "FluxAmplitude": float(np.max(Flux) - np.min(Flux)),
        "FluxPercentAmplitude95To5": float(P95 - P05),
        "FluxPercentAmplitude90To10": float(P90 - P10),
        "FluxSkewness": float(skew(Flux, bias=False)) if CadenceCount >= 3 and FluxStd > Eps else np.nan,
        "FluxKurtosis": float(kurtosis(Flux, bias=False)) if CadenceCount >= 4 and FluxStd > Eps else np.nan,
    }

# %% [markdown]
# # Tail-Asymmetry Features

# %%
def ExtractTailAsymmetryFeatures(Flux: np.ndarray) -> Dict[str, float]:
    P05, P50, P95 = np.percentile(Flux, [5, 50, 95])

    TailUpper = float(P95 - P50)
    TailLower = float(P50 - P05)
    TailAsymmetry = float(TailUpper - TailLower)
    TailRatio = SafeDivide(TailUpper, TailLower + Eps)

    return {
        "TailUpper": TailUpper,
        "TailLower": TailLower,
        "TailAsymmetry": TailAsymmetry,
        "TailRatio": TailRatio,
    }

# %% [markdown]
# # Time-Domain Variability Features

# %%
def ExtractVariabilityFeatures(Time: np.ndarray, Flux: np.ndarray) -> Dict[str, float]:
    CadenceCount = len(Flux)
    if CadenceCount < 3:
        return {
            "EtaVonNeumann": np.nan,
            "MaxAbsSlope": np.nan,
            "MedianAbsSuccessiveDiff": np.nan,
            "FractionBeyond1Std": np.nan,
            "FractionBeyond2Std": np.nan,
        }

    FluxMean = float(np.mean(Flux))
    FluxStd = float(np.std(Flux))
    FluxVariance = float(np.var(Flux))
    FluxDiff = np.diff(Flux)
    TimeDiff = np.diff(Time)

    ValidTimeDiff = np.isfinite(TimeDiff) & (np.abs(TimeDiff) > Eps)
    Slopes = FluxDiff[ValidTimeDiff] / TimeDiff[ValidTimeDiff] if np.any(ValidTimeDiff) else np.array([])

    Eta = np.sum(FluxDiff ** 2) / ((CadenceCount - 1) * FluxVariance) if FluxVariance > Eps else np.nan

    return {
        "EtaVonNeumann": float(Eta) if np.isfinite(Eta) else np.nan,
        "MaxAbsSlope": float(np.max(np.abs(Slopes))) if Slopes.size else np.nan,
        "MedianAbsSuccessiveDiff": float(np.median(np.abs(FluxDiff))),
        "FractionBeyond1Std": float(np.mean(np.abs(Flux - FluxMean) > FluxStd)) if FluxStd > Eps else np.nan,
        "FractionBeyond2Std": float(np.mean(np.abs(Flux - FluxMean) > 2 * FluxStd)) if FluxStd > Eps else np.nan,
    }

# %% [markdown]
# # Lomb-Scargle Period Features

# %%
def ExtractLombScargleFeatures(Time: np.ndarray, Flux: np.ndarray, FluxErr: Optional[np.ndarray]) -> Dict[str, float]:
    Result = {
        "LsBestPeriod": np.nan,
        "LsBestFrequency": np.nan,
        "LsMaxPower": np.nan,
        "LsFalseAlarmProbability": np.nan,
        "LsPeriod2": np.nan,
        "LsPeriod3": np.nan,
        "LsPower2": np.nan,
        "LsPower3": np.nan,
        "LsPowerRatio21": np.nan,
        "LsPowerRatio31": np.nan,
        "LsPeriodRatio21": np.nan,
        "LsPeriodRatio31": np.nan,
    }

    if len(Flux) < MinCadences:
        return Result

    TimeSpan = float(np.max(Time) - np.min(Time))
    if not np.isfinite(TimeSpan) or TimeSpan <= 0:
        return Result

    MaxPeriod = min(MaxPeriodDays, 0.9 * TimeSpan)
    if MaxPeriod <= MinPeriodDays:
        return Result

    CenteredFlux = Flux - np.nanmedian(Flux)

    try:
        if FluxErr is not None and len(FluxErr) == len(Flux) and np.all(np.isfinite(FluxErr)):
            LombScargleModel = LombScargle(Time, CenteredFlux, dy=FluxErr)
        else:
            LombScargleModel = LombScargle(Time, CenteredFlux)

        Frequency, Power = LombScargleModel.autopower(
            minimum_frequency=1.0 / MaxPeriod,
            maximum_frequency=1.0 / MinPeriodDays,
            samples_per_peak=SamplesPerPeak,
        )

        FiniteMask = np.isfinite(Frequency) & np.isfinite(Power) & (Frequency > 0)
        Frequency = Frequency[FiniteMask]
        Power = Power[FiniteMask]
        if len(Power) == 0:
            return Result

        Order = np.argsort(Power)[::-1]
        BestFrequency = float(Frequency[Order[0]])
        BestPeriod = float(1.0 / BestFrequency)
        BestPower = float(Power[Order[0]])

        Result.update({
            "LsBestPeriod": BestPeriod,
            "LsBestFrequency": BestFrequency,
            "LsMaxPower": BestPower,
            "LsFalseAlarmProbability": float(LombScargleModel.false_alarm_probability(BestPower)),
        })

        if len(Order) > 1:
            Period2 = float(1.0 / Frequency[Order[1]])
            Power2 = float(Power[Order[1]])
            Result.update({
                "LsPeriod2": Period2,
                "LsPower2": Power2,
                "LsPowerRatio21": SafeDivide(Power2, BestPower),
                "LsPeriodRatio21": SafeDivide(Period2, BestPeriod),
            })

        if len(Order) > 2:
            Period3 = float(1.0 / Frequency[Order[2]])
            Power3 = float(Power[Order[2]])
            Result.update({
                "LsPeriod3": Period3,
                "LsPower3": Power3,
                "LsPowerRatio31": SafeDivide(Power3, BestPower),
                "LsPeriodRatio31": SafeDivide(Period3, BestPeriod),
            })

    except Exception as Exc:
        Logger.debug("Lomb-Scargle failed: %s", Exc)

    return Result

# %% [markdown]
# # Phase-Folded Morphology Features

# %%
def ExtractPhaseFeatures(Time: np.ndarray, Flux: np.ndarray, Period: float) -> Dict[str, float]:
    Result = {
        "PhaseCurveStd": np.nan,
        "PhaseCurveRange": np.nan,
        "PhaseCurveSmoothness": np.nan,
        "PhasePeakPhase": np.nan,
        "PhaseTroughPhase": np.nan,
        "PhasePeakToTroughPhaseDelta": np.nan,
    }

    if not np.isfinite(Period) or Period <= 0 or len(Flux) < MinCadences:
        return Result

    try:
        Phase = (Time % Period) / Period
        Order = np.argsort(Phase)
        Phase = Phase[Order]
        Flux = Flux[Order]

        BinEdges = np.linspace(0.0, 1.0, PhaseBinCount + 1)
        BinIndex = np.digitize(Phase, BinEdges) - 1

        BinnedPhase = []
        BinnedFlux = []

        for BinNumber in range(PhaseBinCount):
            BinMask = BinIndex == BinNumber
            if np.any(BinMask):
                BinnedPhase.append(float(np.median(Phase[BinMask])))
                BinnedFlux.append(float(np.median(Flux[BinMask])))

        BinnedPhase = np.asarray(BinnedPhase, dtype=float)
        BinnedFlux = np.asarray(BinnedFlux, dtype=float)
        if len(BinnedFlux) < 5:
            return Result

        PeakIndex = int(np.argmax(BinnedFlux))
        TroughIndex = int(np.argmin(BinnedFlux))
        PeakPhase = float(BinnedPhase[PeakIndex])
        TroughPhase = float(BinnedPhase[TroughIndex])

        RawDelta = abs(PeakPhase - TroughPhase)
        CyclicDelta = min(RawDelta, 1.0 - RawDelta)
        CyclicDiff = np.diff(np.r_[BinnedFlux, BinnedFlux[0]])

        Result.update({
            "PhaseCurveStd": float(np.std(BinnedFlux)),
            "PhaseCurveRange": float(np.max(BinnedFlux) - np.min(BinnedFlux)),
            "PhaseCurveSmoothness": float(np.std(CyclicDiff)),
            "PhasePeakPhase": PeakPhase,
            "PhaseTroughPhase": TroughPhase,
            "PhasePeakToTroughPhaseDelta": float(CyclicDelta),
        })

    except Exception as Exc:
        Logger.debug("Phase feature extraction failed: %s", Exc)

    return Result

# %% [markdown]
# # Per-Star Feature Extraction

# %%
def ExtractFeaturesForRow(Row: pd.Series, MetadataPath: Path) -> Dict[str, Any]:
    fitsBasePath = Path("/data/projects/TESS-research/data_pipeline")
    Result: Dict[str, Any] = {
        "FeatureStatus": "unknown",
        "FeatureError": None,
    }

    Result.update(ExtractIdentifierAndMetadataFeatures(Row))
    # LightCurvePath = ResolvePath(Row.get("lightCurvePath"), MetadataPath)
    LightCurvePath = Path(fitsBasePath / Row.get("lightCurvePath"))

    if LightCurvePath is None:
        Result["FeatureStatus"] = "missing_lightcurve_path"
        Result["FeatureError"] = "No lightCurvePath"
        return Result

    if not LightCurvePath.exists():
        Result["FeatureStatus"] = "missing_lightcurve_file"
        Result["FeatureError"] = str(LightCurvePath)
        return Result

    try:
        Time, Flux, FluxErr = LoadLightCurve(LightCurvePath)

        if len(Flux) < MinCadences:
            Result["FeatureStatus"] = "too_few_cadences"
            Result["FeatureError"] = f"Only {len(Flux)} finite cadences"
            Result["CadenceCount"] = float(len(Flux))
            return Result

        Result.update(ExtractBasicStatisticalFeatures(Time, Flux))
        Result.update(ExtractTailAsymmetryFeatures(Flux))
        Result.update(ExtractVariabilityFeatures(Time, Flux))

        LombScargleFeatures = ExtractLombScargleFeatures(Time, Flux, FluxErr)
        Result.update(LombScargleFeatures)

        BestPeriod = LombScargleFeatures.get("LsBestPeriod", np.nan)
        Result.update(ExtractPhaseFeatures(Time, Flux, BestPeriod))

        Result["FeatureStatus"] = "ok"

    except Exception as Exc:
        Result["FeatureStatus"] = "failed"
        Result["FeatureError"] = repr(Exc)

    return Result

# %% [markdown]
# # Dataset-Level Feature Extraction with Parallel Processing

# %%
def FinalizeFeatureDf(FeatureDf: pd.DataFrame) -> pd.DataFrame:
    if "_InputOrder" in FeatureDf.columns:
        FeatureDf = FeatureDf.sort_values("_InputOrder").drop(columns=["_InputOrder"]).reset_index(drop=True)
    return FeatureDf


def ExtractFeaturesSerial(MetadataDf: pd.DataFrame, MetadataPath: Path) -> pd.DataFrame:
    ResultRows = []
    for Position, (_, Row) in enumerate(MetadataDf.iterrows()):
        if Position % 100 == 0:
            Logger.info("Processing %s/%s", Position, len(MetadataDf))
        FeatureRow = ExtractFeaturesForRow(Row, MetadataPath)
        FeatureRow["_InputOrder"] = Position
        ResultRows.append(FeatureRow)
    return FinalizeFeatureDf(pd.DataFrame(ResultRows))


def ExtractFeaturesParallel(MetadataDf: pd.DataFrame, MetadataPath: Path, WorkerCount: int = WorkerCount) -> pd.DataFrame:
    ResultRows = []
    TotalRows = len(MetadataDf)
    Logger.info("Starting parallel feature extraction with WorkerCount=%s", WorkerCount)

    with ThreadPoolExecutor(max_workers=WorkerCount) as Executor:
        FutureMap = {}
        for Position, (_, Row) in enumerate(MetadataDf.iterrows()):
            Future = Executor.submit(ExtractFeaturesForRow, Row, MetadataPath)
            FutureMap[Future] = Position

        CompletedCount = 0
        for Future in as_completed(FutureMap):
            Position = FutureMap[Future]
            try:
                FeatureRow = Future.result()
            except Exception as Exc:
                FeatureRow = {"FeatureStatus": "failed", "FeatureError": repr(Exc)}

            FeatureRow["_InputOrder"] = Position
            ResultRows.append(FeatureRow)
            CompletedCount += 1

            if CompletedCount % 100 == 0 or CompletedCount == TotalRows:
                Logger.info("Completed %s/%s", CompletedCount, TotalRows)

    return FinalizeFeatureDf(pd.DataFrame(ResultRows))


def ExtractFeatures(MetadataDf: pd.DataFrame, MetadataPath: Path, WorkerCount: int = WorkerCount) -> pd.DataFrame:
    if WorkerCount <= 1:
        return ExtractFeaturesSerial(MetadataDf, MetadataPath)
    return ExtractFeaturesParallel(MetadataDf, MetadataPath, WorkerCount=WorkerCount)

# %% [markdown]
# # Execute Feature Extraction

# %%
MetadataDf = pd.read_parquet(InputMetadataPath)

FeatureDf = ExtractFeatures(
    MetadataDf=MetadataDf,
    MetadataPath=InputMetadataPath,
    WorkerCount=WorkerCount,
)

OutputFeaturePath.parent.mkdir(parents=True, exist_ok=True)
FeatureDf.to_parquet(OutputFeaturePath, index=False)

print(f"Saved {len(FeatureDf)} rows and {len(FeatureDf.columns)} columns to {OutputFeaturePath}")
FeatureDf["FeatureStatus"].value_counts(dropna=False)
# Out:
# 2026-07-27 23:56:51,026 INFO:FeatureExtractorNotebook:Starting parallel feature extraction with WorkerCount=16
# 0% (0/12767) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,398 INFO:lightkurve.utils:0% (0/12767) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28154) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,420 INFO:lightkurve.utils:0% (0/28154) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,430 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/18678) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,432 INFO:lightkurve.utils:0% (0/18678) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32158) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,446 INFO:lightkurve.utils:0% (0/32158) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/47803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,457 INFO:lightkurve.utils:0% (0/47803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,549 INFO:lightkurve.utils:0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/53566) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/26793) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,563 INFO:lightkurve.utils:0% (0/53566) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/40096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,569 INFO:lightkurve.utils:0% (0/26793) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,604 INFO:lightkurve.utils:0% (0/40096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/281759) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,642 INFO:lightkurve.utils:0% (0/281759) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/36973) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:51,704 INFO:lightkurve.utils:0% (0/36973) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25041) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:53,167 INFO:lightkurve.utils:0% (0/25041) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/3011) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:54,126 INFO:lightkurve.utils:0% (0/3011) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/26486) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:54,384 INFO:lightkurve.utils:0% (0/26486) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:55,316 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/10828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:56,037 INFO:lightkurve.utils:0% (0/10828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/35355) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:56,142 INFO:lightkurve.utils:0% (0/35355) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:56,698 INFO:lightkurve.utils:0% (0/23270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/254238) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:57,237 INFO:lightkurve.utils:0% (0/254238) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:57,671 INFO:lightkurve.utils:0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14258) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:57,988 INFO:lightkurve.utils:0% (0/14258) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:58,097 INFO:lightkurve.utils:0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17196) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:58,155 INFO:lightkurve.utils:0% (0/17196) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:58,240 INFO:lightkurve.utils:0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:58,357 INFO:lightkurve.utils:0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/75851) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:58,360 INFO:lightkurve.utils:0% (0/75851) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:58,635 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/18975) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:58,697 INFO:lightkurve.utils:0% (0/18975) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/291089) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:59,079 INFO:lightkurve.utils:0% (0/291089) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14655) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:56:59,871 INFO:lightkurve.utils:0% (0/14655) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13339) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:00,535 INFO:lightkurve.utils:0% (0/13339) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/41364) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:00,904 INFO:lightkurve.utils:0% (0/41364) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/27265) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:00,988 INFO:lightkurve.utils:0% (0/27265) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/53331) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:01,275 INFO:lightkurve.utils:0% (0/53331) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/2843) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:01,491 INFO:lightkurve.utils:0% (0/2843) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/16167) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:02,012 INFO:lightkurve.utils:0% (0/16167) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17598) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:02,048 INFO:lightkurve.utils:0% (0/17598) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:02,244 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14785) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:02,434 INFO:lightkurve.utils:0% (0/14785) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:02,551 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25143) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:02,733 INFO:lightkurve.utils:0% (0/25143) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:02,787 INFO:lightkurve.utils:0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:03,191 INFO:lightkurve.utils:0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52376) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:03,552 INFO:lightkurve.utils:0% (0/52376) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:03,938 INFO:lightkurve.utils:0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4458) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:04,063 INFO:lightkurve.utils:0% (0/4458) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/20736) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:04,598 INFO:lightkurve.utils:0% (0/20736) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:05,293 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32102) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:05,359 INFO:lightkurve.utils:0% (0/32102) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32315) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:05,793 INFO:lightkurve.utils:0% (0/32315) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/271390) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:05,948 INFO:lightkurve.utils:0% (0/271390) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/42271) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:05,990 INFO:lightkurve.utils:0% (0/42271) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13317) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:06,195 INFO:lightkurve.utils:0% (0/13317) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23075) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:06,899 INFO:lightkurve.utils:0% (0/23075) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/35132) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:06,904 INFO:lightkurve.utils:0% (0/35132) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4942) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:07,226 INFO:lightkurve.utils:0% (0/4942) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/9058) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:07,549 INFO:lightkurve.utils:0% (0/9058) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/58244) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:07,590 INFO:lightkurve.utils:0% (0/58244) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/39085) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:08,260 INFO:lightkurve.utils:0% (0/39085) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/46263) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:08,530 INFO:lightkurve.utils:0% (0/46263) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19468) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:09,046 INFO:lightkurve.utils:0% (0/19468) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11948) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:09,472 INFO:lightkurve.utils:0% (0/11948) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23099) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:09,708 INFO:lightkurve.utils:0% (0/23099) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:09,724 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14055) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:10,175 INFO:lightkurve.utils:0% (0/14055) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/254238) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:10,327 INFO:lightkurve.utils:0% (0/254238) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/58278) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:10,391 INFO:lightkurve.utils:0% (0/58278) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24254) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:10,849 INFO:lightkurve.utils:0% (0/24254) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:11,634 INFO:lightkurve.utils:0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/64915) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:11,647 INFO:lightkurve.utils:0% (0/64915) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/37793) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:11,652 INFO:lightkurve.utils:0% (0/37793) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/20498) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:11,926 INFO:lightkurve.utils:0% (0/20498) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/21346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:11,937 INFO:lightkurve.utils:0% (0/21346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43291) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:12,043 INFO:lightkurve.utils:0% (0/43291) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/276410) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:12,253 INFO:lightkurve.utils:0% (0/276410) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:12,888 INFO:lightkurve.utils:0% (0/32101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/53831) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:13,267 INFO:lightkurve.utils:0% (0/53831) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19881) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:13,500 INFO:lightkurve.utils:0% (0/19881) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/47803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:13,507 INFO:lightkurve.utils:0% (0/47803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/33867) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:14,284 INFO:lightkurve.utils:0% (0/33867) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:14,655 INFO:lightkurve.utils:0% (0/22096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24319) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:14,896 INFO:lightkurve.utils:0% (0/24319) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25138) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:15,046 INFO:lightkurve.utils:0% (0/25138) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/57998) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:15,214 INFO:lightkurve.utils:0% (0/57998) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14367) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:15,699 INFO:lightkurve.utils:0% (0/14367) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4017) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:15,883 INFO:lightkurve.utils:0% (0/4017) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4449) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:15,915 INFO:lightkurve.utils:0% (0/4449) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24829) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:16,344 INFO:lightkurve.utils:0% (0/24829) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:16,682 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/42450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:17,114 INFO:lightkurve.utils:0% (0/42450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/88826) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:17,202 INFO:lightkurve.utils:0% (0/88826) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:17,515 INFO:FeatureExtractorNotebook:Completed 100/7294
# 0% (0/19768) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:17,773 INFO:lightkurve.utils:0% (0/19768) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:18,143 INFO:lightkurve.utils:0% (0/23270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/62270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:18,313 INFO:lightkurve.utils:0% (0/62270) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/36180) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:18,317 INFO:lightkurve.utils:0% (0/36180) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/67641) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:18,451 INFO:lightkurve.utils:0% (0/67641) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11473) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:19,030 INFO:lightkurve.utils:0% (0/11473) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:19,043 INFO:lightkurve.utils:0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/16987) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:19,173 INFO:lightkurve.utils:0% (0/16987) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:19,369 INFO:lightkurve.utils:0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/18851) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:19,656 INFO:lightkurve.utils:0% (0/18851) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11065) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:19,852 INFO:lightkurve.utils:0% (0/11065) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/291333) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:20,420 INFO:lightkurve.utils:0% (0/291333) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/53615) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:20,674 INFO:lightkurve.utils:0% (0/53615) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13308) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:21,475 INFO:lightkurve.utils:0% (0/13308) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:21,910 INFO:lightkurve.utils:0% (0/19450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/44861) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:22,136 INFO:lightkurve.utils:0% (0/44861) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17144) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:22,151 INFO:lightkurve.utils:0% (0/17144) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13442) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:22,747 INFO:lightkurve.utils:0% (0/13442) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/7935) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:23,054 INFO:lightkurve.utils:0% (0/7935) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13482) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:23,309 INFO:lightkurve.utils:0% (0/13482) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:23,648 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25806) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:23,829 INFO:lightkurve.utils:0% (0/25806) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/10399) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:24,412 INFO:lightkurve.utils:0% (0/10399) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23416) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:24,981 INFO:lightkurve.utils:0% (0/23416) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:25,261 INFO:lightkurve.utils:0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/66298) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:25,265 INFO:lightkurve.utils:0% (0/66298) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:26,002 INFO:lightkurve.utils:0% (0/14624) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:26,213 INFO:lightkurve.utils:0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/64915) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:26,220 INFO:lightkurve.utils:0% (0/64915) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4478) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:26,332 INFO:lightkurve.utils:0% (0/4478) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17013) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:26,469 INFO:lightkurve.utils:0% (0/17013) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:26,559 INFO:lightkurve.utils:0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/29810) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:26,742 INFO:lightkurve.utils:0% (0/29810) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/291101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:27,363 INFO:lightkurve.utils:0% (0/291101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/27796) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:27,375 INFO:lightkurve.utils:0% (0/27796) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32123) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:28,324 INFO:lightkurve.utils:0% (0/32123) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4942) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:28,425 INFO:lightkurve.utils:0% (0/4942) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17517) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:28,474 INFO:lightkurve.utils:0% (0/17517) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/54024) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:28,484 INFO:lightkurve.utils:0% (0/54024) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/44933) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:28,506 INFO:lightkurve.utils:0% (0/44933) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/97313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:28,771 INFO:lightkurve.utils:0% (0/97313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/17222) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:28,961 INFO:lightkurve.utils:0% (0/17222) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11608) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:29,642 INFO:lightkurve.utils:0% (0/11608) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/2926) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:29,843 INFO:lightkurve.utils:0% (0/2926) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/45095) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:30,167 INFO:lightkurve.utils:0% (0/45095) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:30,354 INFO:lightkurve.utils:0% (0/19803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/34934) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:30,558 INFO:lightkurve.utils:0% (0/34934) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/42450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:30,617 INFO:lightkurve.utils:0% (0/42450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/10828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:30,660 INFO:lightkurve.utils:0% (0/10828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/13392) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:31,371 INFO:lightkurve.utils:0% (0/13392) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/58278) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:31,846 INFO:lightkurve.utils:0% (0/58278) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22228) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:32,310 INFO:lightkurve.utils:0% (0/22228) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:32,658 INFO:lightkurve.utils:0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4615) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:32,828 INFO:lightkurve.utils:0% (0/4615) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/26809) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:33,261 INFO:lightkurve.utils:0% (0/26809) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:33,581 INFO:lightkurve.utils:0% (0/11346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28823) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:33,808 INFO:lightkurve.utils:0% (0/28823) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32144) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:33,981 INFO:lightkurve.utils:0% (0/32144) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/23656) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:34,182 INFO:lightkurve.utils:0% (0/23656) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/15627) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:34,266 INFO:lightkurve.utils:0% (0/15627) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/287970) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:34,343 INFO:lightkurve.utils:0% (0/287970) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19527) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:34,351 INFO:lightkurve.utils:0% (0/19527) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52480) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:34,371 INFO:lightkurve.utils:0% (0/52480) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/48812) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:35,113 INFO:lightkurve.utils:0% (0/48812) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4765) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:35,323 INFO:lightkurve.utils:0% (0/4765) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:35,399 INFO:lightkurve.utils:0% (0/19450) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:35,484 INFO:lightkurve.utils:0% (0/24638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/2424) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:35,610 INFO:lightkurve.utils:0% (0/2424) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/56983) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:35,626 INFO:lightkurve.utils:0% (0/56983) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24829) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:36,172 INFO:lightkurve.utils:0% (0/24829) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:36,184 INFO:lightkurve.utils:0% (0/19770) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/15212) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:36,700 INFO:lightkurve.utils:0% (0/15212) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/34526) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:37,042 INFO:lightkurve.utils:0% (0/34526) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24782) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:37,838 INFO:lightkurve.utils:0% (0/24782) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:38,304 INFO:lightkurve.utils:0% (0/43439) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11033) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:39,047 INFO:lightkurve.utils:0% (0/11033) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/80991) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:39,152 INFO:lightkurve.utils:0% (0/80991) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:39,950 INFO:FeatureExtractorNotebook:Completed 200/7294
# 0% (0/14498) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:39,967 INFO:lightkurve.utils:0% (0/14498) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/64979) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:40,233 INFO:lightkurve.utils:0% (0/64979) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:40,277 INFO:lightkurve.utils:0% (0/52596) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/31267) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:40,308 INFO:lightkurve.utils:0% (0/31267) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:40,359 INFO:lightkurve.utils:0% (0/22472) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25423) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:40,390 INFO:lightkurve.utils:0% (0/25423) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:40,974 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/294782) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:41,491 INFO:lightkurve.utils:0% (0/294782) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/43021) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:42,538 INFO:lightkurve.utils:0% (0/43021) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/37201) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:42,544 INFO:lightkurve.utils:0% (0/37201) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4934) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:43,245 INFO:lightkurve.utils:0% (0/4934) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/57027) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:43,419 INFO:lightkurve.utils:0% (0/57027) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4116) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:44,261 INFO:lightkurve.utils:0% (0/4116) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/19803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:44,587 INFO:lightkurve.utils:0% (0/19803) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/41338) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:45,433 INFO:lightkurve.utils:0% (0/41338) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/33421) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:45,449 INFO:lightkurve.utils:0% (0/33421) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/10399) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:46,379 INFO:lightkurve.utils:0% (0/10399) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14963) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:46,535 INFO:lightkurve.utils:0% (0/14963) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/47010) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:46,714 INFO:lightkurve.utils:0% (0/47010) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/71479) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:46,809 INFO:lightkurve.utils:0% (0/71479) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/22228) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:47,186 INFO:lightkurve.utils:0% (0/22228) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28159) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:47,533 INFO:lightkurve.utils:0% (0/28159) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:47,585 INFO:lightkurve.utils:0% (0/51313) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:48,094 INFO:lightkurve.utils:0% (0/11346) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/4462) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:48,344 INFO:lightkurve.utils:0% (0/4462) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/32101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:48,762 INFO:lightkurve.utils:0% (0/32101) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/14611) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:49,149 INFO:lightkurve.utils:0% (0/14611) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/40096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:49,630 INFO:lightkurve.utils:0% (0/40096) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/57828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:49,918 INFO:lightkurve.utils:0% (0/57828) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/2464) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:50,000 INFO:lightkurve.utils:0% (0/2464) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/46681) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:50,090 INFO:lightkurve.utils:0% (0/46681) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/24223) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:50,339 INFO:lightkurve.utils:0% (0/24223) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25325) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:50,343 INFO:lightkurve.utils:0% (0/25325) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/9060) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:50,685 INFO:lightkurve.utils:0% (0/9060) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/11234) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-27 23:57:51,022 INFO:lightkurve.utils:0% (0/11234) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# ...
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:46,602 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:47,243 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:47,250 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:47,424 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:47,969 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:48,199 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:48,341 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:48,646 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:48,998 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:49,389 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:50,348 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:50,818 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:51,306 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:51,692 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:51,876 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:52,069 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:52,780 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:53,101 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:53,526 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:53,529 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/15568) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:53,904 INFO:lightkurve.utils:0% (0/15568) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:54,025 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:54,224 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:54,697 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:55,025 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:55,161 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:55,382 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:57,209 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:57,318 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:57,794 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:57,805 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:58,398 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:58,517 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:59,124 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:26:59,916 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:00,579 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:00,738 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:00,825 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:01,106 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:01,330 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:01,417 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:01,558 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:02,455 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:03,271 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:03,622 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:03,917 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:04,381 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:04,489 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:05,233 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:05,681 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:06,708 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25049) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:07,545 INFO:lightkurve.utils:0% (0/25049) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:07,911 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:08,197 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:08,487 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:08,647 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:09,169 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:09,280 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:10,167 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:10,180 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:10,727 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/25049) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:10,870 INFO:lightkurve.utils:0% (0/25049) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:11,055 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:11,161 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:12,831 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:13,476 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:14,016 INFO:lightkurve.utils:0% (0/28638) of the cadences will be ignored due to the quality mask (quality_bitmask=17087).
# 2026-07-28 00:27:16,665 INFO:FeatureExtractorNotebook:Completed 7294/7294
# Saved 7294 rows and 67 columns to /data/projects/TESS-research/feature_extraction/TESS_features.parquet
# FeatureStatus
# ok                  7281
# failed                11
# too_few_cadences       2
# Name: count, dtype: int64

# %% [markdown]
# # Quick Sanity Checks

# %%
display(FeatureDf.head())

NumericColumns = FeatureDf.select_dtypes(include=[np.number]).columns
MissingRate = FeatureDf[NumericColumns].isna().mean().sort_values(ascending=False)
display(MissingRate.head(30))
# Out:
#   FeatureStatus FeatureError   family VSXType                         VSXId  \
# 0            ok          NaN  CEPHEID   DCEPS  Gaia DR3 4685823446113073792
# 1            ok          NaN  CEPHEID     CWB  ASASSN-V J001916.11-180430.8
# 2            ok          NaN  CEPHEID     CWB          CSS_J014935.9+141132
# 3            ok          NaN  CEPHEID    DCEP   Gaia DR3 461049865760507904
# 4            ok          NaN  CEPHEID   DCEPS  Gaia DR3 4662956971490538880
#
#                                       lightCurvePath  \
# 0  /data/projects/TESS-research/data_pipeline/TES...
# 1  /data/projects/TESS-research/data_pipeline/TES...
# 2  /data/projects/TESS-research/data_pipeline/TES...
# 3  /data/projects/TESS-research/data_pipeline/TES...
# 4  /data/projects/TESS-research/data_pipeline/TES...
#
#                                    rawLightCurvePath QualityLabel  \
# 0  /data/projects/TESS-research/data_pipeline/TES...        clean
# 1  /data/projects/TESS-research/data_pipeline/TES...        clean
# 2  /data/projects/TESS-research/data_pipeline/TES...        clean
# 3  /data/projects/TESS-research/data_pipeline/TES...        clean
# 4  /data/projects/TESS-research/data_pipeline/TES...        clean
#
#    QualityScore Provenance  ...  LsPowerRatio21  LsPowerRatio31  \
# 0           0.0    TESSCut  ...        0.965596        0.962654
# 1           0.0    TESSCut  ...        0.991554        0.989106
# 2           0.0    TESSCut  ...        0.988269        0.981074
# 3           0.0        QLP  ...        0.977464        0.976398
# 4           0.0    TESSCut  ...        0.990783        0.915923
#
#    LsPeriodRatio21  LsPeriodRatio31 PhaseCurveStd PhaseCurveRange  \
# 0         1.000523         0.999478      0.108526        0.363780
# 1         1.012854         0.987469      0.160734        0.640752
# 2         1.019496         0.981236      0.346630        1.472735
# 3         0.999790         1.000210      0.073633        0.217096
# 4         1.000500         0.999501      0.034486        0.119370
#
#    PhaseCurveSmoothness  PhasePeakPhase  PhaseTroughPhase  \
# 0              0.089044        0.625510          0.974632
# 1              0.156908        0.787201          0.077085
# 2              0.332614        0.026434          0.275024
# 3              0.025917        0.775062          0.475095
# 4              0.021449        0.675007          0.325098
#
#    PhasePeakToTroughPhaseDelta
# 0                     0.349122
# 1                     0.289884
# 2                     0.248590
# 3                     0.299967
# 4                     0.349909
#
# [5 rows x 67 columns]
# TimeSpanDays                  0.001782
# MedianCadenceDays             0.001782
# FluxMin                       0.001782
# FluxMad                       0.001782
# FluxMedian                    0.001782
# FluxVariance                  0.001782
# FluxStd                       0.001782
# FluxMean                      0.001782
# FluxP05                       0.001782
# FluxP10                       0.001782
# FluxP25                       0.001782
# FluxP75                       0.001782
# FluxP90                       0.001782
# FluxP95                       0.001782
# FluxMax                       0.001782
# FluxP01                       0.001782
# FluxP99                       0.001782
# FluxIqr                       0.001782
# TailUpper                     0.001782
# FluxKurtosis                  0.001782
# FluxSkewness                  0.001782
# FluxPercentAmplitude90To10    0.001782
# FluxPercentAmplitude95To5     0.001782
# FluxAmplitude                 0.001782
# LsMaxPower                    0.001782
# LsFalseAlarmProbability       0.001782
# LsPeriod2                     0.001782
# LsPeriod3                     0.001782
# LsPower2                      0.001782
# LsPower3                      0.001782
# dtype: float64

# %%
if "family" in FeatureDf.columns:
    display(pd.crosstab(FeatureDf["family"], FeatureDf["FeatureStatus"], dropna=False))
# Out:
# FeatureStatus    failed   ok  too_few_cadences
# family
# CEPHEID               0  962                 1
# CV                    0  516                 0
# DSCT_SXPHE            0  968                 0
# ECLIPSING             0  956                 0
# ELLIPSOIDAL_ROT       0  982                 0
# LONG_PERIOD           0  959                 0
# RRLYR                 0  917                 0
# XRAY                  0   51                 0
# YSO                   0  970                 1
# NaN                  11    0                 0
