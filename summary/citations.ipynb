# %% [markdown]
# # TESS Provenance Research Citation Log
#
# This notebook contains the concrete references that have already been used or discussed for this project.

# %% [markdown]
# # 1. TESS Mission
#
# **Reference**
#
# Ricker, G. R., Winn, J. N., Vanderspek, R., et al. (2015). *Transiting Exoplanet Survey Satellite (TESS).* Journal of Astronomical Telescopes, Instruments, and Systems, 1(1), 014003.
#
# DOI: **10.1117/1.JATIS.1.1.014003**
#
# **Used for**
# - Mission description
# - Data source

# %% [markdown]
# # 2. SPOC Pipeline
#
# **Reference**
#
# Jenkins, J. M., Twicken, J. D., McCauliff, S., et al. (2016). *The TESS Science Processing Operations Center.* Proceedings of SPIE, Vol. 9913.
#
# **Used for**
# - SPOC light curves
# - PDCSAP processing

# %% [markdown]
# # 3. QLP Pipeline
#
# **Reference**
#
# Huang, C. X., Vanderburg, A., Pál, A., et al. (2020). *Photometry of 10 Million Stars from the TESS Full-Frame Images: The Quick-Look Pipeline.* Research Notes of the AAS, 4, 204.
#
# DOI: **10.3847/2515-5172/abca2d**
#
# **Used for**
# - QLP provenance

# %% [markdown]
# # 4. TESSCut
#
# **Reference**
#
# Brasseur, C. E., Phillip, C., Fleming, S. W., Mullally, F., & White, R. L. (2019). *Astrocut: Tools for creating cutouts of TESS and Kepler data.* Astrophysics Source Code Library, ascl:1905.007.
#
# https://ascl.net/1905.007
#
# **Used for**
# - TESSCut fallback light curves

# %% [markdown]
# # 5. VSX
#
# **Reference**
#
# Watson, C., Henden, A. A., & Price, A. (2006–present).
#
# *AAVSO International Variable Star Index (VSX).*
#
# https://www.aavso.org/vsx/
#
# **Used for**
# - Variable-star labels
# - VSX→TESS mapping

# %% [markdown]
# # 6. SIMBAD
#
# **Reference**
#
# Wenger, M., Ochsenbein, F., Egret, D., et al. (2000).
#
# *The SIMBAD astronomical database.*
#
# Astronomy & Astrophysics Supplement Series, 143, 9–22.
#
# DOI: **10.1051/aas:2000332**
#
# **Used for**
# - Proper motion
# - Object validation

# %% [markdown]
# # 7. Gaia DR3
#
# **Reference**
#
# Gaia Collaboration, Vallenari, A., Brown, A. G. A., et al. (2023).
#
# *Gaia Data Release 3: Summary of the content and survey properties.*
#
# Astronomy & Astrophysics, 674, A1.
#
# DOI: **10.1051/0004-6361/202243940**
#
# **Used for**
# - Proper-motion discussion

# %% [markdown]
# # 8. Lomb–Scargle
#
# **Reference**
#
# Scargle, J. D. (1982).
#
# *Studies in astronomical time series analysis. II. Statistical aspects of spectral analysis of unevenly spaced data.*
#
# Astrophysical Journal, 263, 835–853.
#
# DOI: **10.1086/160554**
#
# **Used for**
# - Period extraction

# %% [markdown]
# # 9. Random Forest
#
# **Reference**
#
# Breiman, L. (2001).
#
# *Random Forests.*
#
# Machine Learning, 45(1), 5–32.
#
# DOI: **10.1023/A:1010933404324**
#
# **Used for**
# - Main classifier

# %% [markdown]
# # 10. Logistic Regression
#
# **Reference**
#
# Cox, D. R. (1958).
#
# *The Regression Analysis of Binary Sequences.*
#
# Journal of the Royal Statistical Society: Series B, 20(2), 215–242.
#
# **Used for**
# - Baseline classifier

# %% [markdown]
# # 11. Software
#
# ## Astropy
# Astropy Collaboration et al. (2022). *The Astropy Project: Sustaining and Growing a Community-oriented Open-source Project and the Latest Major Release (v5.0).* ApJ, 935, 167.
#
# ## Lightkurve
# Lightkurve Collaboration (2018). *Lightkurve: Kepler and TESS time series analysis in Python.*
#
# https://docs.lightkurve.org/
#
# ## scikit-learn
# Pedregosa, F., et al. (2011). *Scikit-learn: Machine Learning in Python.* JMLR, 12, 2825–2830.
#
# ## NumPy
# Harris, C. R., et al. (2020). *Array programming with NumPy.* Nature, 585, 357–362.
#
# ## pandas
# McKinney, W. (2010). *Data Structures for Statistical Computing in Python.* Proceedings of SciPy.

# %% [markdown]
# # 12. Related Work
#
# ## Fetherolf et al.
#
# This project has repeatedly compared its VSX-first sampling strategy against the TESS-first strategy described by Fetherolf et al.
#
# I cannot safely invent the exact citation because there are multiple astronomy papers by authors named Fetherolf. Once you provide the paper title (or PDF), this section can be completed with the exact bibliographic reference.
